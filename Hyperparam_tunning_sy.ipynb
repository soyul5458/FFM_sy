# %% [markdown]
# ## run_ResMax_cqt_ADD_FFM_pp.py는 모든 조합 튜닝, 따라서 pp사용해서 결과 작성하기

# %%
from scipy.stats import shapiro , normaltest , anderson , kstest

# %% [markdown]
# ## ADD
# ----------

# %%
import numpy as np

import os
import pandas as pd
import pickle
#from models.BCresnet2 import get_BCResNet, get_inputshape
from sklearn.metrics import roc_curve
from utils.DataLoader import data_loader
from utils.Generator0 import DataGenerator, feature_extract_cqt, evalEER,  evalScore, evalEER_f, evalEER_f2, gen_fname


reslist = ['res_pp/'+fnm for fnm in os.listdir('res_pp/')]

data = []
allkeys = []
for i in range(len(reslist)) :
    with open(reslist[i], 'rb') as f:
        data1 = pickle.load(f)
    data.append(data1)
    allkeys += data1.keys()

allkeys = list(set(allkeys))

newlist = {}
for i in range(len(data)) :
    if i == 0 :
        for k1 in allkeys :
            try :
                newlist[k1] = [ data[i][k1] ]
            except :
                newlist[k1] = [-999]
    else :
        for k1 in allkeys :
            try :
                newlist[k1].append(data[i][k1])
            except :
                newlist[k1].append(-999)

df1 = pd.DataFrame(newlist)
df1.eer_val = pd.to_numeric(df1.eer_val)
df1.eer_eval = pd.to_numeric(df1.eer_eval)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-2-3dfcb13d0181> in <module>
#      15 allkeys = []
#      16 for i in range(len(reslist)) :
# ---> 17     with open(reslist[i], 'rb') as f:
#      18         data1 = pickle.load(f)
#      19     data.append(data1)
#
# IsADirectoryError: [Errno 21] Is a directory: 'res_pp/.ipynb_checkpoints'

# %%
len(df1)

# %%
df1

# %%
df1[111:114][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']]
# Out:
#            model beta_param lowpass highpass ranfilter2  eer_val  eer_eval
# 111  ResMax_ADD_      False   False    False      False   0.0004    0.2125
# 112  ResMax_ADD_      False   False    False      False   0.0004    0.2007
# 113  ResMax_ADD_      False   False    False      False   0.0003    0.2381

# %% [markdown]
# ## None

# %%
df1[df1.beta_param== False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#              model beta_param lowpass highpass ranfilter2  eer_val  eer_eval
# 82   BCResMax_ADD_      False   False    False      False   0.0004    0.1803
# 83   BCResMax_ADD_      False   False    False      False   0.0004    0.2045
# 81   BCResMax_ADD_      False   False    False      False   7.6884    0.2234
# 108   DDWSseq_ADD_      False   False    False      False   0.0004    0.2024
# 109   DDWSseq_ADD_      False   False    False      False   0.0013    0.2220
# 110   DDWSseq_ADD_      False   False    False      False   0.0007    0.2367
# 56       LCNN_ADD_      False   False    False      False   0.0003    0.1916
# 54       LCNN_ADD_      False   False    False      False   0.0004    0.1947
# 55       LCNN_ADD_      False   False    False      False   0.0003    0.2087
# 112    ResMax_ADD_      False   False    False      False   0.0004    0.2007
# 111    ResMax_ADD_      False   False    False      False   0.0004    0.2125
# 113    ResMax_ADD_      False   False    False      False   0.0003    0.2381

# %%
df1[df1.beta_param== False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1803       0.202733      0.021604
# 1   DDWSseq_ADD_        0.2024       0.220367      0.017208
# 2      LCNN_ADD_        0.1916       0.198333      0.009111
# 3    ResMax_ADD_        0.2007       0.217100      0.019120

# %% [markdown]
# ## Mixup

# %%
df1[df1.beta_param!= False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#              model beta_param lowpass highpass ranfilter2  eer_val  eer_eval
# 80   BCResMax_ADD_        0.7   False    False      False   0.0012    0.1541
# 79   BCResMax_ADD_        0.7   False    False      False   0.0037    0.1814
# 78   BCResMax_ADD_        0.7   False    False      False   0.0016    0.1923
# 107   DDWSseq_ADD_        0.7   False    False      False   0.0005    0.1426
# 106   DDWSseq_ADD_        0.7   False    False      False   0.0002    0.1643
# 105   DDWSseq_ADD_        0.7   False    False      False   0.0000    0.1744
# 52       LCNN_ADD_        0.7   False    False      False   5.7663    0.1699
# 51       LCNN_ADD_        0.7   False    False      False   7.6884    0.1821
# 53       LCNN_ADD_        0.7   False    False      False   0.0007    0.2017
# 2      ResMax_ADD_        0.7   False    False      False   3.8442    0.1339
# 0      ResMax_ADD_        0.7   False    False      False   3.8442    0.1541
# 1      ResMax_ADD_        0.7   False    False      False   0.0004    0.1766

# %%
df1[df1.beta_param!= False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1541       0.175933      0.019678
# 1   DDWSseq_ADD_        0.1426       0.160433      0.016249
# 2      LCNN_ADD_        0.1699       0.184567      0.016043
# 3    ResMax_ADD_        0.1339       0.154867      0.021360

# %% [markdown]
# ### Lowpass

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 == False][['model', 'beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model beta_param                              lowpass highpass  \
# 57  BCResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 58  BCResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 59  BCResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 85   DDWSseq_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 84   DDWSseq_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 86   DDWSseq_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 25      LCNN_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 26      LCNN_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 24      LCNN_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 3     ResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 4     ResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 5     ResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
#
#    ranfilter2  eer_val  eer_eval
# 57      False   1.9221    0.1097
# 58      False   5.7663    0.1674
# 59      False   0.0005    0.1674
# 85      False   0.0009    0.1657
# 84      False   0.0002    0.1667
# 86      False   0.0013    0.1681
# 25      False   1.9221    0.1759
# 26      False   1.9221    0.1923
# 24      False   0.0000    0.1961
# 3       False   0.0000    0.1440
# 4       False   0.0003    0.1534
# 5       False   0.0000    0.1681

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1097       0.148167      0.033313
# 1   DDWSseq_ADD_        0.1657       0.166833      0.001206
# 2      LCNN_ADD_        0.1759       0.188100      0.010735
# 3    ResMax_ADD_        0.1440       0.155167      0.012147

# %% [markdown]
# ## Highpass

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 == False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model lowpass                                        highpass  \
# 61  BCResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 62  BCResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 60  BCResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 89   DDWSseq_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 87   DDWSseq_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 88   DDWSseq_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 28      LCNN_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 29      LCNN_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 27      LCNN_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 6     ResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 8     ResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 7     ResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
#
#    ranfilter2  eer_val  eer_eval
# 61      False   0.0000    0.1230
# 62      False   0.0010    0.1643
# 60      False   0.0025    0.1674
# 89      False   7.6884    0.1590
# 87      False   0.0013    0.1706
# 88      False   0.0007    0.1836
# 28      False   0.0002    0.1888
# 29      False   0.0004    0.2024
# 27      False   0.0000    0.2073
# 6       False   0.0003    0.1776
# 8       False   0.0006    0.1993
# 7       False   0.0004    0.2063

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1230       0.151567      0.024788
# 1   DDWSseq_ADD_        0.1590       0.171067      0.012307
# 2      LCNN_ADD_        0.1888       0.199500      0.009585
# 3    ResMax_ADD_        0.1776       0.194400      0.014964

# %% [markdown]
# ## RP

# %%
df1[df1.highpass == False][df1.lowpass == False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model beta_param lowpass highpass                 ranfilter2  \
# 64  BCResMax_ADD_        0.7   False    False    [2, [8, 9, 10, 11, 12]]
# 65  BCResMax_ADD_        0.7   False    False    [2, [8, 9, 10, 11, 12]]
# 63  BCResMax_ADD_        0.7   False    False    [2, [8, 9, 10, 11, 12]]
# 92   DDWSseq_ADD_        0.7   False    False    [2, [8, 9, 10, 11, 12]]
# 90   DDWSseq_ADD_        0.7   False    False    [2, [8, 9, 10, 11, 12]]
# 91   DDWSseq_ADD_        0.7   False    False    [2, [8, 9, 10, 11, 12]]
# 30      LCNN_ADD_        0.7   False    False    [2, [8, 9, 10, 11, 12]]
# 32      LCNN_ADD_        0.7   False    False    [2, [8, 9, 10, 11, 12]]
# 31      LCNN_ADD_        0.7   False    False    [2, [8, 9, 10, 11, 12]]
# 11    ResMax_ADD_        0.7   False    False    [2, [8, 9, 10, 11, 12]]
# 9     ResMax_ADD_        0.7   False    False    [2, [8, 9, 10, 11, 12]]
# 10    ResMax_ADD_        0.7   False    False    [2, [8, 9, 10, 11, 12]]
# 35     ResMax_LA_        0.7   False    False  [2, [10, 11, 12, 13, 14]]
# 38     ResMax_LA_        0.7   False    False  [2, [10, 11, 12, 13, 14]]
# 33     ResMax_LA_        0.7   False    False  [2, [10, 11, 12, 13, 14]]
#
#     eer_val  eer_eval
# 64   0.0003    0.1279
# 65   0.0009    0.1370
# 63   7.6884    0.1377
# 92   0.0000    0.1206
# 90   0.0003    0.1706
# 91   0.0004    0.1961
# 30   3.8442    0.1814
# 32   0.0003    0.1853
# 31   0.0000    0.2087
# 11   0.0000    0.1370
# 9    1.9221    0.1667
# 10   0.0000    0.1790
# 35   0.0081    0.0457
# 38   0.0110    0.0481
# 33   0.0058    0.0495

# %%
df1[df1.highpass == False][df1.lowpass == False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1279       0.134200      0.005467
# 1   DDWSseq_ADD_        0.1206       0.162433      0.038407
# 2      LCNN_ADD_        0.1814       0.191800      0.014765
# 3    ResMax_ADD_        0.1370       0.160900      0.021592
# 4     ResMax_LA_        0.0457       0.047767      0.001922

# %% [markdown]
# ## LP+ HP

# %%
df1[df1.highpass != False][df1.lowpass != False][df1.ranfilter2 == False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#              model                              lowpass  \
# 73   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 74   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 72   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 100   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 101   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 99    DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 47       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 46       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 45       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 18     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 19     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 20     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
#
#                                            highpass ranfilter2  eer_val  \
# 73   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   9.6105
# 74   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0004
# 72   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0008
# 100  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0006
# 101  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0002
# 99   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0005
# 47   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0000
# 46   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0000
# 45   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0000
# 18   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0000
# 19   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0004
# 20   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0002
#
#      eer_eval
# 73     0.1353
# 74     0.1549
# 72     0.1744
# 100    0.1426
# 101    0.1751
# 99     0.1831
# 47     0.1995
# 46     0.2014
# 45     0.2135
# 18     0.1877
# 19     0.1898
# 20     0.1993

# %%
df1[df1.highpass != False][df1.lowpass != False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1353       0.154867      0.019550
# 1   DDWSseq_ADD_        0.1426       0.166933      0.021450
# 2      LCNN_ADD_        0.1995       0.204800      0.007594
# 3    ResMax_ADD_        0.1877       0.192267      0.006181

# %% [markdown]
# ## LP + RP

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model                              lowpass highpass  \
# 68  BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 66  BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 67  BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 93   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 95   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 94   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 36      LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 34      LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 37      LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 14    ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 13    ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 12    ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 42     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 40     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 44     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
#
#                  ranfilter2  eer_val  eer_eval
# 68  [2, [8, 9, 10, 11, 12]]   0.0000    0.1160
# 66  [2, [8, 9, 10, 11, 12]]   0.0004    0.1363
# 67  [2, [8, 9, 10, 11, 12]]   5.7663    0.1440
# 93  [2, [8, 9, 10, 11, 12]]   0.0003    0.1167
# 95  [2, [8, 9, 10, 11, 12]]   0.0000    0.1387
# 94  [2, [8, 9, 10, 11, 12]]   1.9221    0.1681
# 36  [2, [8, 9, 10, 11, 12]]   0.0000    0.1776
# 34  [2, [8, 9, 10, 11, 12]]   0.0000    0.2087
# 37  [2, [8, 9, 10, 11, 12]]   0.0002    0.2087
# 14  [2, [8, 9, 10, 11, 12]]   0.0000    0.1534
# 13  [2, [8, 9, 10, 11, 12]]   0.0000    0.1699
# 12  [2, [8, 9, 10, 11, 12]]   0.0000    0.1744
# 42  [2, [8, 9, 10, 11, 12]]   0.0077    0.0395
# 40  [2, [8, 9, 10, 11, 12]]   0.0069    0.0454
# 44  [2, [8, 9, 10, 11, 12]]   0.0074    0.0504

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1160       0.132100      0.014465
# 1   DDWSseq_ADD_        0.1167       0.141167      0.025789
# 2      LCNN_ADD_        0.1776       0.198333      0.017956
# 3    ResMax_ADD_        0.1534       0.165900      0.011057
# 4     ResMax_LA_        0.0395       0.045100      0.005456

# %% [markdown]
# ## HP + RP

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model lowpass                                        highpass  \
# 71  BCResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 69  BCResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 70  BCResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 97   DDWSseq_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 98   DDWSseq_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 96   DDWSseq_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 39      LCNN_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 41      LCNN_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 43      LCNN_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 17    ResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 15    ResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 16    ResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
#
#                  ranfilter2  eer_val  eer_eval
# 71  [2, [8, 9, 10, 11, 12]]   0.0004    0.1223
# 69  [2, [8, 9, 10, 11, 12]]   3.8442    0.1363
# 70  [2, [8, 9, 10, 11, 12]]   0.0000    0.1744
# 97  [2, [8, 9, 10, 11, 12]]   0.0002    0.1464
# 98  [2, [8, 9, 10, 11, 12]]   0.0004    0.1472
# 96  [2, [8, 9, 10, 11, 12]]   0.0003    0.1594
# 39  [2, [8, 9, 10, 11, 12]]   0.0010    0.1790
# 41  [2, [8, 9, 10, 11, 12]]   0.0008    0.1884
# 43  [2, [8, 9, 10, 11, 12]]   1.9221    0.1957
# 17  [2, [8, 9, 10, 11, 12]]   0.0005    0.1751
# 15  [2, [8, 9, 10, 11, 12]]   1.9221    0.1846
# 16  [2, [8, 9, 10, 11, 12]]   0.0003    0.1961

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1223       0.144333      0.026963
# 1   DDWSseq_ADD_        0.1464       0.151000      0.007286
# 2      LCNN_ADD_        0.1790       0.187700      0.008372
# 3    ResMax_ADD_        0.1751       0.185267      0.010516

# %% [markdown]
# ## HP + LP + RP

# %%
df1[df1.highpass != False ][df1.highpass !=-999][df1.lowpass != False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#              model                              lowpass  \
# 76   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 77   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 75   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 104   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 103   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 102   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 50       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 49       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 48       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 23     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 22     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 21     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
#
#                                            highpass               ranfilter2  \
# 76   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 77   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 75   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 104  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 103  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 102  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 50   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 49   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 48   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 23   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 22   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 21   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
#
#      eer_val  eer_eval
# 76    0.0003    0.1199
# 77    0.0003    0.1283
# 75    0.0005    0.1570
# 104   0.0000    0.1332
# 103   0.0009    0.1621
# 102   0.0008    0.1654
# 50    0.0000    0.1884
# 49    0.0000    0.1916
# 48    0.0002    0.2125
# 23    5.7663    0.1800
# 22    0.0010    0.1968
# 21    0.0004    0.2055

# %%
df1[df1.highpass != False ][df1.highpass !=-999][df1.lowpass != False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1199       0.135067      0.019454
# 1   DDWSseq_ADD_        0.1332       0.153567      0.017715
# 2      LCNN_ADD_        0.1884       0.197500      0.013089
# 3    ResMax_ADD_        0.1800       0.194100      0.012963

# %% [markdown]
# ## cutout

# %%
df1[df1.highpass == -999][df1.cutout != False][['model','beta_param','lowpass','highpass','ranfilter2','cutout','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#              model beta_param lowpass highpass ranfilter2 cutout  eer_val  \
# 146  BCResMax_ADD_        0.7    -999     -999       -999    0.7   0.0008
# 145  BCResMax_ADD_        0.7    -999     -999       -999    0.7   0.0033
# 144  BCResMax_ADD_        0.7    -999     -999       -999    0.7   0.0005
# 158   DDWSseq_ADD_        0.7    -999     -999       -999    0.7   0.0012
# 156   DDWSseq_ADD_        0.7    -999     -999       -999    0.7   0.0024
# 157   DDWSseq_ADD_        0.7    -999     -999       -999    0.7   0.0007
# 134      LCNN_ADD_        0.7    -999     -999       -999    0.7   0.0002
# 133      LCNN_ADD_        0.7    -999     -999       -999    0.7   0.0004
# 132      LCNN_ADD_        0.7    -999     -999       -999    0.7   0.0012
# 121    ResMax_ADD_        0.7    -999     -999       -999    0.7   0.0003
# 120    ResMax_ADD_        0.7    -999     -999       -999    0.7   0.0014
# 122    ResMax_ADD_        0.7    -999     -999       -999    0.7   0.0018
#
#      eer_eval
# 146    0.1636
# 145    0.1681
# 144    0.1986
# 158    0.1541
# 156    0.1597
# 157    0.1751
# 134    0.2094
# 133    0.2234
# 132    0.2251
# 121    0.1681
# 120    0.1891
# 122    0.2087

# %%
df1[df1.highpass == -999][df1.cutout != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1636       0.176767      0.019042
# 1   DDWSseq_ADD_        0.1541       0.162967      0.010874
# 2      LCNN_ADD_        0.2094       0.219300      0.008616
# 3    ResMax_ADD_        0.1681       0.188633      0.020304

# %% [markdown]
# ## cutmix

# %%
df1[df1.highpass == -999][df1.cutmix != False][['model','beta_param','lowpass','highpass','ranfilter2','cutmix','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#              model beta_param lowpass highpass ranfilter2 cutmix  eer_val  \
# 148  BCResMax_ADD_        0.7    -999     -999       -999    0.7   0.0012
# 149  BCResMax_ADD_        0.7    -999     -999       -999    0.7   0.0021
# 147  BCResMax_ADD_        0.7    -999     -999       -999    0.7   0.0047
# 160   DDWSseq_ADD_        0.7    -999     -999       -999    0.7   0.0076
# 161   DDWSseq_ADD_        0.7    -999     -999       -999    0.7   0.0056
# 159   DDWSseq_ADD_        0.7    -999     -999       -999    0.7   0.0065
# 136      LCNN_ADD_        0.7    -999     -999       -999    0.7   0.0015
# 135      LCNN_ADD_        0.7    -999     -999       -999    0.7   0.0013
# 137      LCNN_ADD_        0.7    -999     -999       -999    0.7   0.0035
# 124    ResMax_ADD_        0.7    -999     -999       -999    0.7   0.0022
# 125    ResMax_ADD_        0.7    -999     -999       -999    0.7   0.0065
# 123    ResMax_ADD_        0.7    -999     -999       -999    0.7   0.0063
#
#      eer_eval
# 148    0.1961
# 149    0.2094
# 147    0.2265
# 160    0.1954
# 161    0.2174
# 159    0.2335
# 136    0.2073
# 135    0.2125
# 137    0.2688
# 124    0.2342
# 125    0.2485
# 123    0.2524

# %%
df1[df1.highpass == -999][df1.cutmix != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1961       0.210667      0.015240
# 1   DDWSseq_ADD_        0.1954       0.215433      0.019126
# 2      LCNN_ADD_        0.2073       0.229533      0.034105
# 3    ResMax_ADD_        0.2342       0.245033      0.009582

# %% [markdown]
# ## Specaug

# %%
df1[df1.highpass == -999][df1.specaug != False][['model','beta_param','lowpass','highpass','ranfilter2','specaug','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#              model beta_param lowpass highpass ranfilter2             specaug  \
# 140  BCResMax_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 138  BCResMax_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 139  BCResMax_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 152   DDWSseq_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 151   DDWSseq_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 150   DDWSseq_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 126      LCNN_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 128      LCNN_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 127      LCNN_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 116    ResMax_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 114    ResMax_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 115    ResMax_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
#
#      eer_val  eer_eval
# 140   0.0000    0.1262
# 138   0.0000    0.1402
# 139   0.0006    0.1573
# 152   0.0008    0.1486
# 151   0.0017    0.1573
# 150   0.0002    0.1619
# 126   0.0000    0.1541
# 128   0.0000    0.1751
# 127   0.0000    0.1916
# 116   0.0000    0.1556
# 114   0.0000    0.1573
# 115   0.0000    0.1674

# %%
df1[df1.highpass == -999][df1.specaug != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1262       0.141233      0.015576
# 1   DDWSseq_ADD_        0.1486       0.155933      0.006755
# 2      LCNN_ADD_        0.1541       0.173600      0.018795
# 3    ResMax_ADD_        0.1556       0.160100      0.006379

# %% [markdown]
# ## Specmix

# %%
df1[df1.highpass == -999][df1.specmix != False][['model','beta_param','lowpass','highpass','ranfilter2','specmix','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#              model beta_param lowpass highpass ranfilter2             specmix  \
# 143  BCResMax_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 142  BCResMax_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 141  BCResMax_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 153   DDWSseq_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 155   DDWSseq_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 154   DDWSseq_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 129      LCNN_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 131      LCNN_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 130      LCNN_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 119    ResMax_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 117    ResMax_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
# 118    ResMax_ADD_        0.7    -999     -999       -999  [[2, 13], [2, 15]]
#
#      eer_val  eer_eval
# 143   1.9221    0.1450
# 142   0.0012    0.1631
# 141   0.0013    0.1947
# 153   0.0003    0.1580
# 155   0.0003    0.1604
# 154   0.0012    0.2003
# 129   0.0000    0.1304
# 131   0.0000    0.1580
# 130   0.0003    0.1814
# 119   0.0003    0.1206
# 117   5.7663    0.1394
# 118   5.7663    0.1420

# %%
df1[df1.highpass == -999][df1.specmix != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1450         0.1676      0.025154
# 1   DDWSseq_ADD_        0.1580         0.1729      0.023759
# 2      LCNN_ADD_        0.1304         0.1566      0.025529
# 3    ResMax_ADD_        0.1206         0.1340      0.011677

# %% [markdown]
# ## 가장 성능이 좋은 모델 확인

# %%
df1[df1.model!="ResMax_LA_"][df1.eer_eval <= 0.15][['model','lowpass','highpass','ranfilter2','specmix','eer_val','eer_eval']].sort_values('eer_eval')
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#              model                              lowpass  \
# 57   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 68   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 93    DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 76   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 119    ResMax_ADD_                                 -999
# 92    DDWSseq_ADD_                                False
# 71   BCResMax_ADD_                                False
# 61   BCResMax_ADD_                                False
# 140  BCResMax_ADD_                                 -999
# 64   BCResMax_ADD_                                False
# 77   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 129      LCNN_ADD_                                 -999
# 104   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 2      ResMax_ADD_                                False
# 73   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 69   BCResMax_ADD_                                False
# 66   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 11     ResMax_ADD_                                False
# 65   BCResMax_ADD_                                False
# 63   BCResMax_ADD_                                False
# 95    DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 117    ResMax_ADD_                                 -999
# 138  BCResMax_ADD_                                 -999
# 118    ResMax_ADD_                                 -999
# 100   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 107   DDWSseq_ADD_                                False
# 67   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 3      ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 143  BCResMax_ADD_                                 -999
# 97    DDWSseq_ADD_                                False
# 98    DDWSseq_ADD_                                False
# 152   DDWSseq_ADD_                                 -999
#
#                                            highpass               ranfilter2  \
# 57                                            False                    False
# 68                                            False  [2, [8, 9, 10, 11, 12]]
# 93                                            False  [2, [8, 9, 10, 11, 12]]
# 76   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 119                                            -999                     -999
# 92                                            False  [2, [8, 9, 10, 11, 12]]
# 71   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 61   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]                    False
# 140                                            -999                     -999
# 64                                            False  [2, [8, 9, 10, 11, 12]]
# 77   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 129                                            -999                     -999
# 104  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 2                                             False                    False
# 73   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]                    False
# 69   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 66                                            False  [2, [8, 9, 10, 11, 12]]
# 11                                            False  [2, [8, 9, 10, 11, 12]]
# 65                                            False  [2, [8, 9, 10, 11, 12]]
# 63                                            False  [2, [8, 9, 10, 11, 12]]
# 95                                            False  [2, [8, 9, 10, 11, 12]]
# 117                                            -999                     -999
# 138                                            -999                     -999
# 118                                            -999                     -999
# 100  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]                    False
# 107                                           False                    False
# 67                                            False  [2, [8, 9, 10, 11, 12]]
# 3                                             False                    False
# 143                                            -999                     -999
# 97   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 98   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 152                                            -999                     -999
#
#                 specmix  eer_val  eer_eval
# 57                 -999   1.9221    0.1097
# 68                 -999   0.0000    0.1160
# 93                 -999   0.0003    0.1167
# 76                 -999   0.0003    0.1199
# 119  [[2, 13], [2, 15]]   0.0003    0.1206
# 92                 -999   0.0000    0.1206
# 71                 -999   0.0004    0.1223
# 61                 -999   0.0000    0.1230
# 140               False   0.0000    0.1262
# 64                 -999   0.0003    0.1279
# 77                 -999   0.0003    0.1283
# 129  [[2, 13], [2, 15]]   0.0000    0.1304
# 104                -999   0.0000    0.1332
# 2                  -999   3.8442    0.1339
# 73                 -999   9.6105    0.1353
# 69                 -999   3.8442    0.1363
# 66                 -999   0.0004    0.1363
# 11                 -999   0.0000    0.1370
# 65                 -999   0.0009    0.1370
# 63                 -999   7.6884    0.1377
# 95                 -999   0.0000    0.1387
# 117  [[2, 13], [2, 15]]   5.7663    0.1394
# 138               False   0.0000    0.1402
# 118  [[2, 13], [2, 15]]   5.7663    0.1420
# 100                -999   0.0006    0.1426
# 107                -999   0.0005    0.1426
# 67                 -999   5.7663    0.1440
# 3                  -999   0.0000    0.1440
# 143  [[2, 13], [2, 15]]   1.9221    0.1450
# 97                 -999   0.0002    0.1464
# 98                 -999   0.0004    0.1472
# 152               False   0.0008    0.1486

# %% [markdown]
# # ASV
# ----------------

# %%
import numpy as np

import os
import pandas as pd
import pickle
#from models.BCresnet2 import get_BCResNet, get_inputshape
from sklearn.metrics import roc_curve
from utils.DataLoader import data_loader
from utils.Generator0 import DataGenerator, feature_extract_cqt, evalEER,  evalScore, evalEER_f, evalEER_f2, gen_fname


reslist = ['res_pp2/'+fnm for fnm in os.listdir('res_pp2/')]

data = []
allkeys = []
for i in range(len(reslist)) :
    with open(reslist[i], 'rb') as f:
        data1 = pickle.load(f)
    data.append(data1)
    allkeys += data1.keys()

allkeys = list(set(allkeys))

newlist = {}
for i in range(len(data)) :
    if i == 0 :
        for k1 in allkeys :
            try :
                newlist[k1] = [ data[i][k1] ]
            except :
                newlist[k1] = [-999]
    else :
        for k1 in allkeys :
            try :
                newlist[k1].append(data[i][k1])
            except :
                newlist[k1].append(-999)

df1 = pd.DataFrame(newlist)
df1.eer_val = pd.to_numeric(df1.eer_val)
df1.eer_eval = pd.to_numeric(df1.eer_eval)

# %% [markdown]
# ## None

# %%
df1[df1.beta_param== False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model beta_param lowpass highpass ranfilter2  eer_val  eer_eval
# 43   BCResMax_LA_      False   False    False      False   0.0044    0.0267
# 42   BCResMax_LA_      False   False    False      False   0.0043    0.0310
# 44   BCResMax_LA_      False   False    False      False   0.0058    0.0343
# 71    DDWSseq_LA_      False   False    False      False   0.0051    0.0202
# 69    DDWSseq_LA_      False   False    False      False   0.0043    0.0293
# 70    DDWSseq_LA_      False   False    False      False   0.0044    0.0323
# 101      LCNN_LA_      False   False    False      False   0.0062    0.0313
# 100      LCNN_LA_      False   False    False      False   0.0059    0.0322
# 99       LCNN_LA_      False   False    False      False   0.0066    0.0343
# 97     ResMax_LA_      False   False    False      False   0.0061    0.0400
# 98     ResMax_LA_      False   False    False      False   0.0080    0.0440
# 96     ResMax_LA_      False   False    False      False   0.0084    0.0499

# %%
df1[df1.beta_param== False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0267       0.030667      0.003811
# 1   DDWSseq_LA_        0.0202       0.027267      0.006301
# 2      LCNN_LA_        0.0313       0.032600      0.001539
# 3    ResMax_LA_        0.0400       0.044633      0.004980

# %% [markdown]
# ## Mixup

# %%
df1[df1.beta_param!= False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model beta_param lowpass highpass ranfilter2  eer_val  eer_eval
# 45  BCResMax_LA_        0.7   False    False      False   0.0079    0.0384
# 46  BCResMax_LA_        0.7   False    False      False   0.0078    0.0393
# 47  BCResMax_LA_        0.7   False    False      False   0.0054    0.0416
# 72   DDWSseq_LA_        0.7   False    False      False   0.0057    0.0278
# 74   DDWSseq_LA_        0.7   False    False      False   0.0079    0.0311
# 73   DDWSseq_LA_        0.7   False    False      False   0.0053    0.0376
# 20      LCNN_LA_        0.7   False    False      False   0.0045    0.0272
# 18      LCNN_LA_        0.7   False    False      False   0.0038    0.0278
# 19      LCNN_LA_        0.7   False    False      False   0.0051    0.0307
# 0     ResMax_LA_        0.7   False    False      False   0.0053    0.0325
# 2     ResMax_LA_        0.7   False    False      False   0.0067    0.0355
# 1     ResMax_LA_        0.7   False    False      False   0.0085    0.0357

# %%
df1[df1.beta_param != False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0384       0.039767      0.001650
# 1   DDWSseq_LA_        0.0278       0.032167      0.004986
# 2      LCNN_LA_        0.0272       0.028567      0.001872
# 3    ResMax_LA_        0.0325       0.034567      0.001793

# %% [markdown]
# ### Lowpass

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 == False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model                              lowpass highpass ranfilter2  \
# 49  BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False      False
# 48  BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False      False
# 50  BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False      False
# 77   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False      False
# 76   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False      False
# 75   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False      False
# 22      LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False      False
# 21      LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False      False
# 23      LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False      False
# 5     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False      False
# 3     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False      False
# 4     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False      False
#
#     eer_val  eer_eval
# 49   0.0071    0.0431
# 48   0.0067    0.0433
# 50   0.0071    0.0531
# 77   0.0064    0.0278
# 76   0.0053    0.0320
# 75   0.0052    0.0348
# 22   0.0040    0.0285
# 21   0.0068    0.0294
# 23   0.0051    0.0323
# 5    0.0045    0.0345
# 3    0.0065    0.0357
# 4    0.0072    0.0360

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0431       0.046500      0.005717
# 1   DDWSseq_LA_        0.0278       0.031533      0.003523
# 2      LCNN_LA_        0.0285       0.030067      0.001986
# 3    ResMax_LA_        0.0345       0.035400      0.000794

# %% [markdown]
# ## Highpass

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 == False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model lowpass                            highpass ranfilter2  \
# 53  BCResMax_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]      False
# 51  BCResMax_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]      False
# 52  BCResMax_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]      False
# 78   DDWSseq_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]      False
# 79   DDWSseq_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]      False
# 80   DDWSseq_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]      False
# 26      LCNN_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]      False
# 24      LCNN_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]      False
# 25      LCNN_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]      False
# 6     ResMax_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]      False
# 7     ResMax_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]      False
# 8     ResMax_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]      False
#
#     eer_val  eer_eval
# 53   0.0055    0.0205
# 51   0.0063    0.0275
# 52   0.0075    0.0277
# 78   0.0044    0.0283
# 79   0.0070    0.0288
# 80   0.0069    0.0341
# 26   0.0034    0.0155
# 24   0.0036    0.0164
# 25   0.0027    0.0192
# 6    0.0042    0.0192
# 7    0.0050    0.0221
# 8    0.0038    0.0232

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0205       0.025233      0.004100
# 1   DDWSseq_LA_        0.0283       0.030400      0.003214
# 2      LCNN_LA_        0.0155       0.017033      0.001930
# 3    ResMax_LA_        0.0192       0.021500      0.002066

# %% [markdown]
# ## RP

# %%
df1[df1.highpass == False][df1.lowpass == False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model lowpass highpass               ranfilter2  eer_val  eer_eval
# 55  BCResMax_LA_   False    False  [2, [8, 9, 10, 11, 12]]   0.0057    0.0451
# 54  BCResMax_LA_   False    False  [2, [8, 9, 10, 11, 12]]   0.0068    0.0501
# 56  BCResMax_LA_   False    False  [2, [8, 9, 10, 11, 12]]   0.0049    0.0590
# 81   DDWSseq_LA_   False    False  [2, [8, 9, 10, 11, 12]]   0.0050    0.0488
# 83   DDWSseq_LA_   False    False  [2, [8, 9, 10, 11, 12]]   0.0078    0.0508
# 82   DDWSseq_LA_   False    False  [2, [8, 9, 10, 11, 12]]   0.0076    0.0554
# 28      LCNN_LA_   False    False  [2, [8, 9, 10, 11, 12]]   0.0042    0.0284
# 29      LCNN_LA_   False    False  [2, [8, 9, 10, 11, 12]]   0.0039    0.0301
# 27      LCNN_LA_   False    False  [2, [8, 9, 10, 11, 12]]   0.0039    0.0339

# %%
df1[df1.highpass == False][df1.lowpass == False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0451       0.051400      0.007041
# 1   DDWSseq_LA_        0.0488       0.051667      0.003384
# 2      LCNN_LA_        0.0284       0.030800      0.002816

# %% [markdown]
# ## LP + HP

# %%
df1[df1.highpass != False][df1.lowpass != False][df1.ranfilter2 == False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model                              lowpass  \
# 65  BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 64  BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 63  BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 91   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 92   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 90   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 38      LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 36      LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 37      LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 14    ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 13    ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 12    ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
#
#                                           highpass ranfilter2  eer_val  \
# 65  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0037
# 64  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0082
# 63  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0090
# 91  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0047
# 92  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0070
# 90  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0073
# 38  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0047
# 36  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0038
# 37  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0050
# 14              [[0.5, 0.5], [78, 79, 80, 81, 82]]      False   0.0059
# 13              [[0.5, 0.5], [78, 79, 80, 81, 82]]      False   0.0063
# 12              [[0.5, 0.5], [78, 79, 80, 81, 82]]      False   0.0054
#
#     eer_eval
# 65    0.0231
# 64    0.0270
# 63    0.0350
# 91    0.0311
# 92    0.0355
# 90    0.0429
# 38    0.0208
# 36    0.0227
# 37    0.0244
# 14    0.0244
# 13    0.0246
# 12    0.0256

# %%
df1[df1.highpass != False][df1.lowpass != False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0231       0.028367      0.006067
# 1   DDWSseq_LA_        0.0311       0.036500      0.005963
# 2      LCNN_LA_        0.0208       0.022633      0.001801
# 3    ResMax_LA_        0.0244       0.024867      0.000643

# %% [markdown]
# ## LP + RP

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model                              lowpass highpass  \
# 59  BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 57  BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 58  BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 85   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 84   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 86   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 30      LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 31      LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 32      LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
#
#                  ranfilter2  eer_val  eer_eval
# 59  [2, [8, 9, 10, 11, 12]]   0.0081    0.0459
# 57  [2, [8, 9, 10, 11, 12]]   0.0096    0.0481
# 58  [2, [8, 9, 10, 11, 12]]   0.0086    0.0499
# 85  [2, [8, 9, 10, 11, 12]]   0.0091    0.0465
# 84  [2, [8, 9, 10, 11, 12]]   0.0055    0.0521
# 86  [2, [8, 9, 10, 11, 12]]   0.0062    0.0539
# 30  [2, [8, 9, 10, 11, 12]]   0.0050    0.0291
# 31  [2, [8, 9, 10, 11, 12]]   0.0049    0.0368
# 32  [2, [8, 9, 10, 11, 12]]   0.0038    0.0395

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0459       0.047967      0.002003
# 1   DDWSseq_LA_        0.0465       0.050833      0.003859
# 2      LCNN_LA_        0.0291       0.035133      0.005397

# %% [markdown]
# ## HP + RP

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model lowpass                            highpass  \
# 60  BCResMax_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]
# 62  BCResMax_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]
# 61  BCResMax_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]
# 88   DDWSseq_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]
# 89   DDWSseq_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]
# 87   DDWSseq_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]
# 34      LCNN_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]
# 35      LCNN_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]
# 33      LCNN_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]
# 11    ResMax_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]
# 10    ResMax_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]
# 9     ResMax_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]
#
#                  ranfilter2  eer_val  eer_eval
# 60  [2, [8, 9, 10, 11, 12]]   0.0068    0.0287
# 62  [2, [8, 9, 10, 11, 12]]   0.0080    0.0293
# 61  [2, [8, 9, 10, 11, 12]]   0.0062    0.0391
# 88  [2, [8, 9, 10, 11, 12]]   0.0067    0.0330
# 89  [2, [8, 9, 10, 11, 12]]   0.0067    0.0408
# 87  [2, [8, 9, 10, 11, 12]]   0.0074    0.0484
# 34  [2, [8, 9, 10, 11, 12]]   0.0041    0.0261
# 35  [2, [8, 9, 10, 11, 12]]   0.0040    0.0279
# 33  [2, [8, 9, 10, 11, 12]]   0.0049    0.0293
# 11  [2, [8, 9, 10, 11, 12]]   0.0068    0.0264
# 10  [2, [8, 9, 10, 11, 12]]   0.0056    0.0278
# 9   [2, [8, 9, 10, 11, 12]]   0.0064    0.0299

# %%
df1[df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0267       0.035217      0.005634
# 1   DDWSseq_LA_        0.0202       0.029717      0.005747
# 2      LCNN_LA_        0.0272       0.030583      0.002689
# 3    ResMax_LA_        0.0325       0.039600      0.006450

# %% [markdown]
# ## LP + HP + RP

# %%
df1[df1.highpass != False][df1.highpass!=-999][df1.lowpass != False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model                              lowpass  \
# 66  BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 68  BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 67  BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 95   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 93   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 94   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 41      LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 39      LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 40      LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 15    ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 16    ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 17    ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
#
#                               highpass               ranfilter2  eer_val  \
# 66  [[0.5, 0.5], [78, 79, 80, 81, 82]]  [2, [8, 9, 10, 11, 12]]   0.0065
# 68  [[0.5, 0.5], [78, 79, 80, 81, 82]]  [2, [8, 9, 10, 11, 12]]   0.0092
# 67  [[0.5, 0.5], [78, 79, 80, 81, 82]]  [2, [8, 9, 10, 11, 12]]   0.0093
# 95  [[0.5, 0.5], [78, 79, 80, 81, 82]]  [2, [8, 9, 10, 11, 12]]   0.0068
# 93  [[0.5, 0.5], [78, 79, 80, 81, 82]]  [2, [8, 9, 10, 11, 12]]   0.0066
# 94  [[0.5, 0.5], [78, 79, 80, 81, 82]]  [2, [8, 9, 10, 11, 12]]   0.0056
# 41  [[0.5, 0.5], [78, 79, 80, 81, 82]]  [2, [8, 9, 10, 11, 12]]   0.0036
# 39  [[0.5, 0.5], [78, 79, 80, 81, 82]]  [2, [8, 9, 10, 11, 12]]   0.0041
# 40  [[0.5, 0.5], [78, 79, 80, 81, 82]]  [2, [8, 9, 10, 11, 12]]   0.0049
# 15  [[0.5, 0.5], [78, 79, 80, 81, 82]]  [2, [8, 9, 10, 11, 12]]   0.0041
# 16  [[0.5, 0.5], [78, 79, 80, 81, 82]]  [2, [8, 9, 10, 11, 12]]   0.0046
# 17  [[0.5, 0.5], [78, 79, 80, 81, 82]]  [2, [8, 9, 10, 11, 12]]   0.0050
#
#     eer_eval
# 66    0.0292
# 68    0.0357
# 67    0.0410
# 95    0.0342
# 93    0.0370
# 94    0.0375
# 41    0.0228
# 39    0.0239
# 40    0.0281
# 15    0.0291
# 16    0.0323
# 17    0.0348

# %%
df1[df1.highpass!=-999][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0267       0.035217      0.005634
# 1   DDWSseq_LA_        0.0202       0.029717      0.005747
# 2      LCNN_LA_        0.0272       0.030583      0.002689
# 3    ResMax_LA_        0.0325       0.039600      0.006450

# %% [markdown]
# ## cutout

# %%
df1[df1.highpass == -999][df1.cutout != False][['model','lowpass','highpass','ranfilter2','cutout','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model lowpass highpass ranfilter2 cutout  eer_val  eer_eval
# 133  BCResMax_LA_    -999     -999       -999    0.7   0.0073    0.0320
# 134  BCResMax_LA_    -999     -999       -999    0.7   0.0066    0.0326
# 132  BCResMax_LA_    -999     -999       -999    0.7   0.0076    0.0376
# 145   DDWSseq_LA_    -999     -999       -999    0.7   0.0064    0.0292
# 144   DDWSseq_LA_    -999     -999       -999    0.7   0.0052    0.0299
# 146   DDWSseq_LA_    -999     -999       -999    0.7   0.0051    0.0337
# 120      LCNN_LA_    -999     -999       -999    0.7   0.0032    0.0209
# 122      LCNN_LA_    -999     -999       -999    0.7   0.0021    0.0266
# 121      LCNN_LA_    -999     -999       -999    0.7   0.0038    0.0297
# 108    ResMax_LA_    -999     -999       -999    0.7   0.0076    0.0314
# 109    ResMax_LA_    -999     -999       -999    0.7   0.0065    0.0314
# 110    ResMax_LA_    -999     -999       -999    0.7   0.0057    0.0357

# %%
df1[df1.highpass==-999][df1.cutout != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0320       0.034067      0.003075
# 1   DDWSseq_LA_        0.0292       0.030933      0.002421
# 2      LCNN_LA_        0.0209       0.025733      0.004464
# 3    ResMax_LA_        0.0314       0.032833      0.002483

# %% [markdown]
# ## cutmix

# %%
df1[df1.highpass == -999][df1.cutmix != False][['model','lowpass','highpass','ranfilter2','cutmix','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model lowpass highpass ranfilter2 cutmix  eer_val  eer_eval
# 137  BCResMax_LA_    -999     -999       -999    0.7   0.0109    0.0335
# 135  BCResMax_LA_    -999     -999       -999    0.7   0.0106    0.0349
# 136  BCResMax_LA_    -999     -999       -999    0.7   0.0124    0.0356
# 147   DDWSseq_LA_    -999     -999       -999    0.7   0.0129    0.0353
# 149   DDWSseq_LA_    -999     -999       -999    0.7   0.0139    0.0373
# 148   DDWSseq_LA_    -999     -999       -999    0.7   0.0133    0.0402
# 125      LCNN_LA_    -999     -999       -999    0.7   0.0114    0.0307
# 123      LCNN_LA_    -999     -999       -999    0.7   0.0125    0.0351
# 124      LCNN_LA_    -999     -999       -999    0.7   0.0105    0.0365
# 112    ResMax_LA_    -999     -999       -999    0.7   0.0114    0.0296
# 113    ResMax_LA_    -999     -999       -999    0.7   0.0120    0.0304
# 111    ResMax_LA_    -999     -999       -999    0.7   0.0140    0.0337

# %%
df1[df1.highpass==-999][df1.cutmix != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0335       0.034667      0.001069
# 1   DDWSseq_LA_        0.0353       0.037600      0.002464
# 2      LCNN_LA_        0.0307       0.034100      0.003027
# 3    ResMax_LA_        0.0296       0.031233      0.002173

# %% [markdown]
# ## specaug

# %%
df1[df1.highpass == -999][df1.specaug != False][['model','lowpass','highpass','ranfilter2','specaug','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model lowpass highpass ranfilter2             specaug  eer_val  \
# 126  BCResMax_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0070
# 127  BCResMax_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0075
# 128  BCResMax_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0099
# 138   DDWSseq_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0057
# 139   DDWSseq_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0074
# 140   DDWSseq_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0056
# 114      LCNN_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0047
# 115      LCNN_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0035
# 116      LCNN_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0036
# 102    ResMax_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0041
# 103    ResMax_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0065
# 104    ResMax_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0107
#
#      eer_eval
# 126    0.0368
# 127    0.0371
# 128    0.0551
# 138    0.0364
# 139    0.0417
# 140    0.0508
# 114    0.0288
# 115    0.0308
# 116    0.0311
# 102    0.0319
# 103    0.0349
# 104    0.0460

# %%
df1[df1.highpass==-999][df1.specaug != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0368       0.043000      0.010480
# 1   DDWSseq_LA_        0.0364       0.042967      0.007283
# 2      LCNN_LA_        0.0288       0.030233      0.001250
# 3    ResMax_LA_        0.0319       0.037600      0.007428

# %% [markdown]
# ## specmix

# %%
df1[df1.highpass == -999][df1.specmix != False][['model','lowpass','highpass','ranfilter2','specmix','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model lowpass highpass ranfilter2             specmix  eer_val  \
# 129  BCResMax_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0076
# 130  BCResMax_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0087
# 131  BCResMax_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0077
# 141   DDWSseq_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0081
# 142   DDWSseq_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0090
# 143   DDWSseq_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0076
# 117      LCNN_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0062
# 118      LCNN_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0055
# 119      LCNN_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0047
# 106    ResMax_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0069
# 105    ResMax_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0069
# 107    ResMax_LA_    -999     -999       -999  [[2, 13], [2, 15]]   0.0091
#
#      eer_eval
# 129    0.0299
# 130    0.0364
# 131    0.0389
# 141    0.0250
# 142    0.0305
# 143    0.0368
# 117    0.0250
# 118    0.0286
# 119    0.0303
# 106    0.0329
# 105    0.0370
# 107    0.0381

# %%
df1[df1.highpass==-999][df1.specmix != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0299       0.035067      0.004646
# 1   DDWSseq_LA_        0.0250       0.030767      0.005905
# 2      LCNN_LA_        0.0250       0.027967      0.002706
# 3    ResMax_LA_        0.0329       0.036000      0.002740

# %% [markdown]
# ## 가장 성능이 좋은 모델 확인

# %%
df1[df1.eer_eval <= 0.020][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']]
# Out:
#          model lowpass                            highpass ranfilter2  \
# 6   ResMax_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]      False
# 24    LCNN_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]      False
# 25    LCNN_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]      False
# 26    LCNN_LA_   False  [[0.5, 0.5], [78, 79, 80, 81, 82]]      False
#
#     eer_val  eer_eval
# 6    0.0042    0.0192
# 24   0.0036    0.0164
# 25   0.0027    0.0192
# 26   0.0034    0.0155

# %% [markdown]
# ---------------------

# %% [markdown]
# ## 1.1 ADD data set(sy돌림)

# %%
import numpy as np

import os
import pandas as pd
import pickle
#from models.BCresnet2 import get_BCResNet, get_inputshape
from sklearn.metrics import roc_curve
from utils.DataLoader import data_loader
from utils.Generator0_blur import DataGenerator, feature_extract_cqt, evalEER,  evalScore, evalEER_f, evalEER_f2, gen_fname


reslist = ['res_mask_ADD/'+fnm for fnm in os.listdir('res_mask_ADD/')]

data = []
allkeys = []
for i in range(len(reslist)) :
    with open(reslist[i], 'rb') as f:
        data1 = pickle.load(f)
    data.append(data1)
    allkeys += data1.keys()

allkeys = list(set(allkeys))

newlist = {}
for i in range(len(data)) :
    if i == 0 :
        for k1 in allkeys :
            try :
                newlist[k1] = [ data[i][k1] ]
            except :
                newlist[k1] = [-999]
    else :
        for k1 in allkeys :
            try :
                newlist[k1].append(data[i][k1])
            except :
                newlist[k1].append(-999)

df1 = pd.DataFrame(newlist)
df1.eer_val = pd.to_numeric(df1.eer_val)
df1.eer_eval = pd.to_numeric(df1.eer_eval)

# %%
df1.to_excel(excel_writer="df1.xlsx")

# %%
len(df1)
# Out:
# 108

# %% [markdown]
# ## None

# %%
df1[df1.eer_val<9] [df1.beta_param== False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model beta_param lowpass highpass ranfilter2  eer_val  eer_eval
# 56  BCResMax_ADD_      False   False    False      False   5.7663    0.2055
# 54  BCResMax_ADD_      False   False    False      False   0.0004    0.2264
# 55  BCResMax_ADD_      False   False    False      False   0.0003    0.2374
# 81   DDWSseq_ADD_      False   False    False      False   0.0003    0.1836
# 83   DDWSseq_ADD_      False   False    False      False   0.0021    0.2290
# 82   DDWSseq_ADD_      False   False    False      False   1.9221    0.2632
# 29      LCNN_ADD_      False   False    False      False   0.0009    0.1954
# 28      LCNN_ADD_      False   False    False      False   0.0004    0.2041
# 27      LCNN_ADD_      False   False    False      False   0.0009    0.2048
# 0     ResMax_ADD_      False   False    False      False   0.0005    0.1968
# 2     ResMax_ADD_      False   False    False      False   0.0003    0.2007
# 1     ResMax_ADD_      False   False    False      False   0.0004    0.2017

# %%
df1[df1.beta_param== False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.2055       0.223100      0.016204
# 1   DDWSseq_ADD_        0.1836       0.225267      0.039931
# 2      LCNN_ADD_        0.1954       0.201433      0.005237
# 3    ResMax_ADD_        0.1968       0.199733      0.002589

# %% [markdown]
# ## Mixup

# %%
df1[df1.beta_param!= False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model beta_param lowpass highpass ranfilter2  eer_val  eer_eval
# 59  BCResMax_ADD_        0.7   False    False      False   0.0000    0.1541
# 58  BCResMax_ADD_        0.7   False    False      False   0.0002    0.1556
# 57  BCResMax_ADD_        0.7   False    False      False   0.0002    0.1664
# 86   DDWSseq_ADD_        0.7   False    False      False   0.0000    0.1534
# 85   DDWSseq_ADD_        0.7   False    False      False   0.0013    0.1776
# 84   DDWSseq_ADD_        0.7   False    False      False   0.0008    0.1846
# 31      LCNN_ADD_        0.7   False    False      False   0.0003    0.1864
# 30      LCNN_ADD_        0.7   False    False      False   0.0000    0.2070
# 32      LCNN_ADD_        0.7   False    False      False   3.8442    0.2108
# 3     ResMax_ADD_        0.7   False    False      False   7.6884    0.1416
# 4     ResMax_ADD_        0.7   False    False      False   3.8442    0.1604
# 5     ResMax_ADD_        0.7   False    False      False   0.0008    0.1660

# %%
df1[df1.beta_param!= False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1541       0.158700      0.006710
# 1   DDWSseq_ADD_        0.1534       0.171867      0.016371
# 2      LCNN_ADD_        0.1864       0.201400      0.013129
# 3    ResMax_ADD_        0.1416       0.156000      0.012781

# %% [markdown]
# ### Lowpass

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 == False][['model', 'beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model beta_param                              lowpass highpass  \
# 62  BCResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 61  BCResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 60  BCResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 88   DDWSseq_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 89   DDWSseq_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 87   DDWSseq_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 35      LCNN_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 34      LCNN_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 33      LCNN_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 7     ResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 8     ResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 6     ResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
#
#    ranfilter2  eer_val  eer_eval
# 62      False   0.0002    0.1517
# 61      False   0.0002    0.1650
# 60      False   0.0000    0.1720
# 88      False   0.0000    0.1523
# 89      False   5.7663    0.1720
# 87      False   1.9221    0.1821
# 35      False   7.6884    0.1884
# 34      False   0.0000    0.1947
# 33      False   0.0000    0.2133
# 7       False   3.8442    0.1496
# 8       False   0.0002    0.1496
# 6       False   9.6105    0.1954

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1517       0.162900      0.010312
# 1   DDWSseq_ADD_        0.1523       0.168800      0.015156
# 2      LCNN_ADD_        0.1884       0.198800      0.012946
# 3    ResMax_ADD_        0.1496       0.164867      0.026443

# %% [markdown]
# ## Highpass

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model beta_param lowpass  \
# 65  BCResMax_ADD_        0.7   False
# 63  BCResMax_ADD_        0.7   False
# 64  BCResMax_ADD_        0.7   False
# 90   DDWSseq_ADD_        0.7   False
# 92   DDWSseq_ADD_        0.7   False
# 91   DDWSseq_ADD_        0.7   False
# 36      LCNN_ADD_        0.7   False
# 37      LCNN_ADD_        0.7   False
# 38      LCNN_ADD_        0.7   False
# 10    ResMax_ADD_        0.7   False
# 11    ResMax_ADD_        0.7   False
# 9     ResMax_ADD_        0.7   False
#
#                                           highpass ranfilter2  eer_val  \
# 65  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0027
# 63  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0015
# 64  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0056
# 90  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0000
# 92  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0014
# 91  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0007
# 36  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   9.6105
# 37  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0004
# 38  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0008
# 10  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0002
# 11  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0004
# 9   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   3.8442
#
#     eer_eval
# 65    0.1373
# 63    0.1636
# 64    0.1807
# 90    0.1621
# 92    0.1783
# 91    0.1790
# 36    0.1783
# 37    0.2041
# 38    0.2087
# 10    0.1597
# 11    0.1783
# 9     0.1831

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1373       0.160533      0.021862
# 1   DDWSseq_ADD_        0.1621       0.173133      0.009562
# 2      LCNN_ADD_        0.1783       0.197033      0.016386
# 3    ResMax_ADD_        0.1597       0.173700      0.012360

# %% [markdown]
# ## RP

# %%
df1[df1.highpass == False][df1.lowpass == False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model beta_param lowpass highpass               ranfilter2  \
# 66  BCResMax_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 68  BCResMax_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 67  BCResMax_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 94   DDWSseq_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 93   DDWSseq_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 95   DDWSseq_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 40      LCNN_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 41      LCNN_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 39      LCNN_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 13    ResMax_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 12    ResMax_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 14    ResMax_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
#
#     eer_val  eer_eval
# 66   3.8442    0.1339
# 68   0.0002    0.1394
# 67   0.0000    0.1472
# 94   0.0007    0.1199
# 93   0.0008    0.1377
# 95   0.0000    0.1443
# 40   0.0000    0.1706
# 41   0.0004    0.1814
# 39   0.0000    0.2014
# 13   3.8442    0.1279
# 12   3.8442    0.1409
# 14   0.0006    0.1877

# %%
df1[df1.highpass == False][df1.lowpass == False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1339       0.140167      0.006683
# 1   DDWSseq_ADD_        0.1199       0.133967      0.012621
# 2      LCNN_ADD_        0.1706       0.184467      0.015627
# 3    ResMax_ADD_        0.1279       0.152167      0.031452

# %% [markdown]
# ## LP+ HP

# %%
df1[df1.highpass != False][df1.lowpass != False][df1.ranfilter2 == False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#              model                              lowpass  \
# 77   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 75   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 76   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 103   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 102   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 104   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 49       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 48       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 50       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 22     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 23     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 21     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
#
#                                            highpass ranfilter2  eer_val  \
# 77   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0010
# 75   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0020
# 76   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   3.8442
# 103  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0003
# 102  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   3.8442
# 104  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0005
# 49   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0000
# 48   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0005
# 50   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0000
# 22   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0000
# 23   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0004
# 21   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0008
#
#      eer_eval
# 77     0.1324
# 75     0.1363
# 76     0.1783
# 103    0.1479
# 102    0.1611
# 104    0.1706
# 49     0.1828
# 48     0.2017
# 50     0.2024
# 22     0.1713
# 23     0.2055
# 21     0.2118

# %%
df1[df1.highpass != False][df1.lowpass != False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1324       0.149000      0.025449
# 1   DDWSseq_ADD_        0.1479       0.159867      0.011400
# 2      LCNN_ADD_        0.1828       0.195633      0.011120
# 3    ResMax_ADD_        0.1713       0.196200      0.021793

# %% [markdown]
# ## LP + RP

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model                              lowpass highpass  \
# 71  BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 69  BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 70  BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 97   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 98   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 96   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 42      LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 43      LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 44      LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 15    ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 16    ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 17    ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
#
#                  ranfilter2  eer_val  eer_eval
# 71  [2, [8, 9, 10, 11, 12]]   0.0003    0.1136
# 69  [2, [8, 9, 10, 11, 12]]   0.0003    0.1160
# 70  [2, [8, 9, 10, 11, 12]]   0.0002    0.1332
# 97  [2, [8, 9, 10, 11, 12]]   0.0009    0.1262
# 98  [2, [8, 9, 10, 11, 12]]   0.0003    0.1619
# 96  [2, [8, 9, 10, 11, 12]]   0.0005    0.1776
# 42  [2, [8, 9, 10, 11, 12]]   0.0002    0.1503
# 43  [2, [8, 9, 10, 11, 12]]   3.8442    0.1713
# 44  [2, [8, 9, 10, 11, 12]]   0.0000    0.1828
# 15  [2, [8, 9, 10, 11, 12]]   0.0000    0.1464
# 16  [2, [8, 9, 10, 11, 12]]   9.6105    0.1783
# 17  [2, [8, 9, 10, 11, 12]]   1.9221    0.1821

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1136       0.120933      0.010691
# 1   DDWSseq_ADD_        0.1262       0.155233      0.026341
# 2      LCNN_ADD_        0.1503       0.168133      0.016480
# 3    ResMax_ADD_        0.1464       0.168933      0.019607

# %% [markdown]
# ## HP + RP

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#              model lowpass                                        highpass  \
# 72   BCResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 73   BCResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 74   BCResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 101   DDWSseq_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 99    DDWSseq_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 100   DDWSseq_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 45       LCNN_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 47       LCNN_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 46       LCNN_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 20     ResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 18     ResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 19     ResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
#
#                   ranfilter2  eer_val  eer_eval
# 72   [2, [8, 9, 10, 11, 12]]   0.0014    0.1230
# 73   [2, [8, 9, 10, 11, 12]]   7.6884    0.1254
# 74   [2, [8, 9, 10, 11, 12]]   0.0000    0.1307
# 101  [2, [8, 9, 10, 11, 12]]   9.6105    0.1433
# 99   [2, [8, 9, 10, 11, 12]]   0.0008    0.1534
# 100  [2, [8, 9, 10, 11, 12]]   0.0000    0.1713
# 45   [2, [8, 9, 10, 11, 12]]   0.0000    0.1986
# 47   [2, [8, 9, 10, 11, 12]]   0.0010    0.1993
# 46   [2, [8, 9, 10, 11, 12]]   0.0007    0.2094
# 20   [2, [8, 9, 10, 11, 12]]   0.0004    0.1681
# 18   [2, [8, 9, 10, 11, 12]]   0.0000    0.1720
# 19   [2, [8, 9, 10, 11, 12]]   1.9221    0.1797

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1230       0.126367      0.003940
# 1   DDWSseq_ADD_        0.1433       0.156000      0.014180
# 2      LCNN_ADD_        0.1986       0.202433      0.006043
# 3    ResMax_ADD_        0.1681       0.173267      0.005903

# %% [markdown]
# ## HP + LP + RP

# %%
df1[df1.highpass != False ][df1.highpass !=-999][df1.lowpass != False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#              model                              lowpass  \
# 80   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 78   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 79   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 107   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 105   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 106   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 51       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 52       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 53       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 25     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 24     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 26     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
#
#                                            highpass               ranfilter2  \
# 80   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 78   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 79   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 107  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 105  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 106  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 51   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 52   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 53   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 25   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 24   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 26   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
#
#      eer_val  eer_eval
# 80    0.0003    0.1167
# 78    0.0004    0.1332
# 79    0.0000    0.1332
# 107   0.0005    0.1597
# 105   5.7663    0.1636
# 106   0.0004    0.1776
# 51    0.0007    0.1891
# 52    0.0005    0.1901
# 53    1.9221    0.1908
# 25    0.0000    0.1559
# 24    0.0008    0.1838
# 26    0.0005    0.1846

# %%
df1[df1.highpass != False ][df1.highpass !=-999][df1.lowpass != False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1167       0.127700      0.009526
# 1   DDWSseq_ADD_        0.1597       0.166967      0.009413
# 2      LCNN_ADD_        0.1891       0.190000      0.000854
# 3    ResMax_ADD_        0.1559       0.174767      0.016344

# %% [markdown]
# ## 1.2 ASV - LA data set(sy 돌림)

# %%
import numpy as np

import os
import pandas as pd
import pickle
#from models.BCresnet2 import get_BCResNet, get_inputshape
from sklearn.metrics import roc_curve
from utils.DataLoader import data_loader
from utils.Generator0 import DataGenerator, feature_extract_cqt, evalEER,  evalScore, evalEER_f, evalEER_f2, gen_fname


reslist = ['res_mask_LA/'+fnm for fnm in os.listdir('res_mask_LA/')]

data = []
allkeys = []
for i in range(len(reslist)) :
    with open(reslist[i], 'rb') as f:
        data1 = pickle.load(f)
    data.append(data1)
    allkeys += data1.keys()

allkeys = list(set(allkeys))

newlist = {}
for i in range(len(data)) :
    if i == 0 :
        for k1 in allkeys :
            try :
                newlist[k1] = [ data[i][k1] ]
            except :
                newlist[k1] = [-999]
    else :
        for k1 in allkeys :
            try :
                newlist[k1].append(data[i][k1])
            except :
                newlist[k1].append(-999)

df1 = pd.DataFrame(newlist)
df1.eer_val = pd.to_numeric(df1.eer_val)
df1.eer_eval = pd.to_numeric(df1.eer_eval)

# %%
df1.to_excel(excel_writer="df1_LA.xlsx")

# %%
len(df1)
# Out:
# 111

# %%
len(df1)
# Out:
# 96

# %%
df1[['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']]
# Out:
#            model beta_param                              lowpass  \
# 0     ResMax_LA_      False                                False
# 1     ResMax_LA_      False                                False
# 2     ResMax_LA_      False                                False
# 3     ResMax_LA_      False                                False
# 4     ResMax_LA_      False                                False
# ..           ...        ...                                  ...
# 106  DDWSseq_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 107  DDWSseq_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 108   ResMax_LA_        0.7                                False
# 109   ResMax_LA_        0.7                                False
# 110   ResMax_LA_        0.7                                False
#
#                                            highpass               ranfilter2  \
# 0                                             False                    False
# 1                                             False                    False
# 2                                             False                    False
# 3                                             False                    False
# 4                                             False                    False
# ..                                              ...                      ...
# 106  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 107  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 108                                           False                    False
# 109                                           False                    False
# 110                                           False                    False
#
#      eer_val  eer_eval
# 0     0.0070    0.0431
# 1     0.0076    0.0450
# 2     0.0086    0.0476
# 3     0.0077    0.0397
# 4     0.0077    0.0535
# ..       ...       ...
# 106   0.0086    0.0504
# 107   0.0063    0.0414
# 108   0.0067    0.0311
# 109   0.0087    0.0333
# 110   0.0085    0.0410
#
# [111 rows x 7 columns]

# %% [markdown]
# ## None

# %%
df1[df1.beta_param== False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model beta_param lowpass highpass ranfilter2  eer_val  eer_eval
# 54  BCResMax_LA_      False   False    False      False   0.0043    0.0342
# 55  BCResMax_LA_      False   False    False      False   0.0050    0.0368
# 56  BCResMax_LA_      False   False    False      False   0.0054    0.0438
# 81   DDWSseq_LA_      False   False    False      False   0.0046    0.0210
# 83   DDWSseq_LA_      False   False    False      False   0.0056    0.0260
# 82   DDWSseq_LA_      False   False    False      False   0.0036    0.0319
# 27      LCNN_LA_      False   False    False      False   0.0050    0.0259
# 28      LCNN_LA_      False   False    False      False   0.0049    0.0342
# 29      LCNN_LA_      False   False    False      False   0.0051    0.0352
# 5     ResMax_LA_      False   False    False      False   0.0067    0.0379
# 3     ResMax_LA_      False   False    False      False   0.0077    0.0397
# 0     ResMax_LA_      False   False    False      False   0.0070    0.0431
# 1     ResMax_LA_      False   False    False      False   0.0076    0.0450
# 2     ResMax_LA_      False   False    False      False   0.0086    0.0476
# 4     ResMax_LA_      False   False    False      False   0.0077    0.0535

# %%
df1[df1.beta_param== False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0342       0.038267      0.004965
# 1   DDWSseq_LA_        0.0210       0.026300      0.005456
# 2      LCNN_LA_        0.0259       0.031767      0.005105
# 3    ResMax_LA_        0.0379       0.044467      0.005646

# %% [markdown]
# ## Mixup

# %%
df1[df1.beta_param!= False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model beta_param lowpass highpass ranfilter2  eer_val  eer_eval
# 59   BCResMax_LA_        0.7   False    False      False   0.0071    0.0345
# 57   BCResMax_LA_        0.7   False    False      False   0.0081    0.0367
# 58   BCResMax_LA_        0.7   False    False      False   0.0073    0.0390
# 86    DDWSseq_LA_        0.7   False    False      False   0.0061    0.0362
# 84    DDWSseq_LA_        0.7   False    False      False   0.0070    0.0403
# 85    DDWSseq_LA_        0.7   False    False      False   0.0050    0.0452
# 31       LCNN_LA_        0.7   False    False      False   0.0036    0.0291
# 32       LCNN_LA_        0.7   False    False      False   0.0033    0.0318
# 30       LCNN_LA_        0.7   False    False      False   0.0040    0.0323
# 108    ResMax_LA_        0.7   False    False      False   0.0067    0.0311
# 109    ResMax_LA_        0.7   False    False      False   0.0087    0.0333
# 110    ResMax_LA_        0.7   False    False      False   0.0085    0.0410

# %%
df1[df1.beta_param!= False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0345       0.036733      0.002250
# 1   DDWSseq_LA_        0.0362       0.040567      0.004506
# 2      LCNN_LA_        0.0291       0.031067      0.001721
# 3    ResMax_LA_        0.0311       0.035133      0.005198

# %% [markdown]
# ### Lowpass

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 == False][['model', 'beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model beta_param                              lowpass highpass  \
# 61  BCResMax_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 60  BCResMax_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 62  BCResMax_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 87   DDWSseq_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 88   DDWSseq_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 89   DDWSseq_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 35      LCNN_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 33      LCNN_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 34      LCNN_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 7     ResMax_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 6     ResMax_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 8     ResMax_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
#
#    ranfilter2  eer_val  eer_eval
# 61      False   0.0039    0.0281
# 60      False   0.0055    0.0311
# 62      False   0.0071    0.0369
# 87      False   0.0043    0.0300
# 88      False   0.0061    0.0311
# 89      False   0.0093    0.0372
# 35      False   0.0044    0.0263
# 33      False   0.0042    0.0274
# 34      False   0.0046    0.0328
# 7       False   0.0062    0.0322
# 6       False   0.0077    0.0371
# 8       False   0.0060    0.0386

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0281       0.032033      0.004474
# 1   DDWSseq_LA_        0.0300       0.032767      0.003879
# 2      LCNN_LA_        0.0263       0.028833      0.003479
# 3    ResMax_LA_        0.0322       0.035967      0.003347

# %% [markdown]
# ## Highpass

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 == False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model lowpass                                        highpass  \
# 64  BCResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 65  BCResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 63  BCResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 90   DDWSseq_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 91   DDWSseq_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 92   DDWSseq_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 38      LCNN_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 37      LCNN_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 36      LCNN_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 9     ResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 10    ResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 11    ResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
#
#    ranfilter2  eer_val  eer_eval
# 64      False   0.0053    0.0236
# 65      False   0.0056    0.0253
# 63      False   0.0059    0.0329
# 90      False   0.0045    0.0240
# 91      False   0.0075    0.0256
# 92      False   0.0062    0.0303
# 38      False   0.0044    0.0187
# 37      False   0.0022    0.0199
# 36      False   0.0034    0.0225
# 9       False   0.0028    0.0194
# 10      False   0.0044    0.0215
# 11      False   0.0059    0.0215

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0236       0.027267      0.004952
# 1   DDWSseq_LA_        0.0240       0.026633      0.003275
# 2      LCNN_LA_        0.0187       0.020367      0.001943
# 3    ResMax_LA_        0.0194       0.020800      0.001212

# %% [markdown]
# ## RP

# %%
df1[df1.highpass == False][df1.lowpass == False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model beta_param lowpass highpass               ranfilter2  \
# 68  BCResMax_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 67  BCResMax_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 66  BCResMax_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 95   DDWSseq_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 94   DDWSseq_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 93   DDWSseq_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 39      LCNN_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 41      LCNN_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 40      LCNN_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 13    ResMax_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 12    ResMax_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 14    ResMax_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
#
#     eer_val  eer_eval
# 68   0.0069    0.0453
# 67   0.0074    0.0515
# 66   0.0072    0.0584
# 95   0.0063    0.0582
# 94   0.0076    0.0655
# 93   0.0088    0.0757
# 39   0.0036    0.0325
# 41   0.0041    0.0355
# 40   0.0066    0.0376
# 13   0.0061    0.0392
# 12   0.0086    0.0453
# 14   0.0062    0.0525

# %%
df1[df1.highpass == False][df1.lowpass == False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0453       0.051733      0.006553
# 1   DDWSseq_LA_        0.0582       0.066467      0.008790
# 2      LCNN_LA_        0.0325       0.035200      0.002563
# 3    ResMax_LA_        0.0392       0.045667      0.006658

# %% [markdown]
# ## LP+ HP

# %%
df1[df1.highpass != False][df1.lowpass != False][df1.ranfilter2 == False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model                              lowpass  \
# 77   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 75   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 76   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 102   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 104   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 103   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 49       LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 50       LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 48       LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 22     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 21     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 23     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
#
#                                            highpass ranfilter2  eer_val  \
# 77   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0069
# 75   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0066
# 76   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0055
# 102  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0058
# 104  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0050
# 103  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0076
# 49   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0031
# 50   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0030
# 48   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0041
# 22   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0070
# 21   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0056
# 23   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0055
#
#      eer_eval
# 77     0.0210
# 75     0.0241
# 76     0.0289
# 102    0.0215
# 104    0.0257
# 103    0.0262
# 49     0.0172
# 50     0.0194
# 48     0.0212
# 22     0.0184
# 21     0.0205
# 23     0.0255

# %%
df1[df1.highpass != False][df1.lowpass != False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0210       0.024667      0.003980
# 1   DDWSseq_LA_        0.0215       0.024467      0.002581
# 2      LCNN_LA_        0.0172       0.019267      0.002003
# 3    ResMax_LA_        0.0184       0.021467      0.003647

# %% [markdown]
# ## LP + RP

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model                              lowpass highpass  \
# 69  BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 71  BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 70  BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 97   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 96   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 98   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 43      LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 44      LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 42      LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 15    ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 17    ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 16    ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
#
#                  ranfilter2  eer_val  eer_eval
# 69  [2, [8, 9, 10, 11, 12]]   0.0053    0.0484
# 71  [2, [8, 9, 10, 11, 12]]   0.0074    0.0489
# 70  [2, [8, 9, 10, 11, 12]]   0.0074    0.0523
# 97  [2, [8, 9, 10, 11, 12]]   0.0081    0.0457
# 96  [2, [8, 9, 10, 11, 12]]   0.0069    0.0474
# 98  [2, [8, 9, 10, 11, 12]]   0.0066    0.0809
# 43  [2, [8, 9, 10, 11, 12]]   0.0043    0.0304
# 44  [2, [8, 9, 10, 11, 12]]   0.0047    0.0313
# 42  [2, [8, 9, 10, 11, 12]]   0.0047    0.0372
# 15  [2, [8, 9, 10, 11, 12]]   0.0082    0.0436
# 17  [2, [8, 9, 10, 11, 12]]   0.0064    0.0483
# 16  [2, [8, 9, 10, 11, 12]]   0.0070    0.0572

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0484       0.049867      0.002122
# 1   DDWSseq_LA_        0.0457       0.058000      0.019850
# 2      LCNN_LA_        0.0304       0.032967      0.003694
# 3    ResMax_LA_        0.0436       0.049700      0.006907

# %% [markdown]
# ## HP + RP

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model lowpass                                        highpass  \
# 74   BCResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 73   BCResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 72   BCResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 99    DDWSseq_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 100   DDWSseq_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 101   DDWSseq_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 47       LCNN_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 46       LCNN_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 45       LCNN_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 18     ResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 20     ResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 19     ResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
#
#                   ranfilter2  eer_val  eer_eval
# 74   [2, [8, 9, 10, 11, 12]]   0.0070    0.0321
# 73   [2, [8, 9, 10, 11, 12]]   0.0050    0.0383
# 72   [2, [8, 9, 10, 11, 12]]   0.0053    0.0514
# 99   [2, [8, 9, 10, 11, 12]]   0.0070    0.0398
# 100  [2, [8, 9, 10, 11, 12]]   0.0072    0.0491
# 101  [2, [8, 9, 10, 11, 12]]   0.0074    0.0546
# 47   [2, [8, 9, 10, 11, 12]]   0.0039    0.0221
# 46   [2, [8, 9, 10, 11, 12]]   0.0030    0.0259
# 45   [2, [8, 9, 10, 11, 12]]   0.0031    0.0288
# 18   [2, [8, 9, 10, 11, 12]]   0.0065    0.0257
# 20   [2, [8, 9, 10, 11, 12]]   0.0060    0.0328
# 19   [2, [8, 9, 10, 11, 12]]   0.0074    0.0377

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0321       0.040600      0.009853
# 1   DDWSseq_LA_        0.0398       0.047833      0.007481
# 2      LCNN_LA_        0.0221       0.025600      0.003360
# 3    ResMax_LA_        0.0257       0.032067      0.006034

# %% [markdown]
# ## HP + LP + RP

# %%
df1[df1.highpass != False ][df1.highpass !=-999][df1.lowpass != False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model                              lowpass  \
# 79   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 78   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 80   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 105   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 107   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 106   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 51       LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 53       LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 52       LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 25     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 24     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 26     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
#
#                                            highpass               ranfilter2  \
# 79   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 78   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 80   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 105  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 107  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 106  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 51   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 53   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 52   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 25   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 24   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 26   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
#
#      eer_val  eer_eval
# 79    0.0054    0.0298
# 78    0.0081    0.0448
# 80    0.0078    0.0557
# 105   0.0070    0.0381
# 107   0.0063    0.0414
# 106   0.0086    0.0504
# 51    0.0027    0.0217
# 53    0.0037    0.0255
# 52    0.0031    0.0262
# 25    0.0053    0.0352
# 24    0.0032    0.0371
# 26    0.0057    0.0412

# %%
df1[df1.highpass != False ][df1.highpass !=-999][df1.lowpass != False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0298       0.043433      0.013004
# 1   DDWSseq_LA_        0.0381       0.043300      0.006366
# 2      LCNN_LA_        0.0217       0.024467      0.002421
# 3    ResMax_LA_        0.0352       0.037833      0.003066

# %% [markdown]
# ## 가장 성능이 좋은 모델 확인

# %%
df1[df1.model!="ResMax_LA_"][df1.eer_eval <= 0.15][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values('eer_eval')
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model                              lowpass  \
# 49      LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 38      LCNN_LA_                                False
# 50      LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 37      LCNN_LA_                                False
# 77  BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# ..           ...                                  ...
# 95   DDWSseq_LA_                                False
# 66  BCResMax_LA_                                False
# 94   DDWSseq_LA_                                False
# 93   DDWSseq_LA_                                False
# 98   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
#
#                                           highpass               ranfilter2  \
# 49  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]                    False
# 38  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]                    False
# 50  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]                    False
# 37  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]                    False
# 77  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]                    False
# ..                                             ...                      ...
# 95                                           False  [2, [8, 9, 10, 11, 12]]
# 66                                           False  [2, [8, 9, 10, 11, 12]]
# 94                                           False  [2, [8, 9, 10, 11, 12]]
# 93                                           False  [2, [8, 9, 10, 11, 12]]
# 98                                           False  [2, [8, 9, 10, 11, 12]]
#
#     eer_val  eer_eval
# 49   0.0031    0.0172
# 38   0.0044    0.0187
# 50   0.0030    0.0194
# 37   0.0022    0.0199
# 77   0.0069    0.0210
# ..      ...       ...
# 95   0.0063    0.0582
# 66   0.0072    0.0584
# 94   0.0076    0.0655
# 93   0.0088    0.0757
# 98   0.0066    0.0809
#
# [81 rows x 6 columns]

# %% [markdown]
# --------------------

# %% [markdown]
# # 2. Blur 적용

# %% [markdown]
# ## 2.1 ADD Data set
# --------

# %%
import numpy as np

import os
import pandas as pd
import pickle
#from models.BCresnet2 import get_BCResNet, get_inputshape
from sklearn.metrics import roc_curve
from utils.DataLoader import data_loader
from utils.Generator0_blur import DataGenerator, feature_extract_cqt, evalEER,  evalScore, evalEER_f, evalEER_f2, gen_fname


reslist = ['res_blur_ADD1/'+fnm for fnm in os.listdir('res_blur_ADD1/')]

data = []
allkeys = []
for i in range(len(reslist)) :
    with open(reslist[i], 'rb') as f:
        data1 = pickle.load(f)
    data.append(data1)
    allkeys += data1.keys()

allkeys = list(set(allkeys))

newlist = {}
for i in range(len(data)) :
    if i == 0 :
        for k1 in allkeys :
            try :
                newlist[k1] = [ data[i][k1] ]
            except :
                newlist[k1] = [-999]
    else :
        for k1 in allkeys :
            try :
                newlist[k1].append(data[i][k1])
            except :
                newlist[k1].append(-999)

df1 = pd.DataFrame(newlist)
df1.eer_val = pd.to_numeric(df1.eer_val)
df1.eer_eval = pd.to_numeric(df1.eer_eval)

# %%
df1.to_excel(excel_writer="df1_blur.xlsx")

# %%
allkeys
# Out:
# ['eer_val',
#  'feature',
#  'eer_eval',
#  'filter_scale',
#  'human_weight',
#  'batch_size',
#  'tnow',
#  'n_classes',
#  'lowpass',
#  'tofile',
#  'data_dir',
#  'shuffle',
#  'highpass',
#  'saved_model',
#  'sr',
#  'sec',
#  'model',
#  'beta_param',
#  'ranfilter2',
#  'n_bins',
#  'dropout_rate',
#  'fmin']

# %%
len(df1)
# Out:
# 117

# %% [markdown]
# ## None

# %%
df1[df1.eer_val<9] [df1.beta_param== False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model beta_param lowpass highpass ranfilter2  eer_val  eer_eval
# 63  BCResMax_ADD_      False   False    False      False   0.0003    0.2195
# 64  BCResMax_ADD_      False   False    False      False   5.7663    0.2282
# 65  BCResMax_ADD_      False   False    False      False   5.7663    0.2408
# 92   DDWSseq_ADD_      False   False    False      False   0.0013    0.2312
# 91   DDWSseq_ADD_      False   False    False      False   0.0012    0.2738
# 90   DDWSseq_ADD_      False   False    False      False   0.0003    0.2772
# 38      LCNN_ADD_      False   False    False      False   0.0004    0.1894
# 36      LCNN_ADD_      False   False    False      False   5.7663    0.2125
# 37      LCNN_ADD_      False   False    False      False   0.0003    0.2213
# 0     ResMax_ADD_      False   False    False      False   0.0011    0.2024
# 1     ResMax_ADD_      False   False    False      False   0.0004    0.2159
# 10    ResMax_ADD_      False   False    False      False   0.0003    0.2405
# 2     ResMax_ADD_      False   False    False      False   0.0002    0.2437

# %%
df1[df1.beta_param== False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.2195       0.229500      0.010709
# 1   DDWSseq_ADD_        0.2312       0.260733      0.025633
# 2      LCNN_ADD_        0.1894       0.207733      0.016476
# 3    ResMax_ADD_        0.2024       0.221100      0.017429

# %% [markdown]
# ## Mixup

# %%
df1[df1.beta_param!= False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model beta_param lowpass highpass ranfilter2  eer_val  eer_eval
# 66  BCResMax_ADD_        0.7   False    False      False   1.9221    0.1503
# 68  BCResMax_ADD_        0.7   False    False      False   9.6105    0.1580
# 67  BCResMax_ADD_        0.7   False    False      False   0.0003    0.1650
# 93   DDWSseq_ADD_        0.7   False    False      False   0.0012    0.1657
# 95   DDWSseq_ADD_        0.7   False    False      False   0.0003    0.1783
# 94   DDWSseq_ADD_        0.7   False    False      False   0.0000    0.2055
# 41      LCNN_ADD_        0.7   False    False      False   0.0000    0.1744
# 40      LCNN_ADD_        0.7   False    False      False   0.0003    0.1818
# 39      LCNN_ADD_        0.7   False    False      False   3.8442    0.1831
# 4     ResMax_ADD_        0.7   False    False      False   0.0000    0.1457
# 5     ResMax_ADD_        0.7   False    False      False   0.0000    0.1472
# 12    ResMax_ADD_        0.7   False    False      False   0.0003    0.1667
# 3     ResMax_ADD_        0.7   False    False      False   1.9221    0.1681
# 14    ResMax_ADD_        0.7   False    False      False   0.0004    0.1846
# 13    ResMax_ADD_        0.7   False    False      False   0.0004    0.1877

# %%
df1[df1.beta_param!= False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1503       0.157767      0.007353
# 1   DDWSseq_ADD_        0.1657       0.183167      0.020341
# 2      LCNN_ADD_        0.1744       0.179767      0.004693
# 3    ResMax_ADD_        0.1457       0.166667      0.017802

# %% [markdown]
# ### Lowpass

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 == False][['model', 'beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model beta_param                              lowpass highpass  \
# 70  BCResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 69  BCResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 71  BCResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 96   DDWSseq_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 97   DDWSseq_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 98   DDWSseq_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 43      LCNN_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 42      LCNN_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 44      LCNN_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 16    ResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 6     ResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 17    ResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 15    ResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 8     ResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 7     ResMax_ADD_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
#
#    ranfilter2  eer_val  eer_eval
# 70      False   0.0004    0.1380
# 69      False   5.7663    0.1394
# 71      False   0.0003    0.1412
# 96      False   0.0006    0.1734
# 97      False   0.0000    0.1768
# 98      False   0.0002    0.2000
# 43      False   0.0000    0.1828
# 42      False   0.0003    0.1940
# 44      False   0.0000    0.2055
# 16      False   0.0000    0.1433
# 6       False   0.0000    0.1657
# 17      False   0.0000    0.1713
# 15      False   0.0000    0.1759
# 8       False   0.0002    0.1821
# 7       False   1.9221    0.2017

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1380       0.139533      0.001604
# 1   DDWSseq_ADD_        0.1734       0.183400      0.014476
# 2      LCNN_ADD_        0.1828       0.194100      0.011350
# 3    ResMax_ADD_        0.1433       0.173333      0.019248

# %% [markdown]
# ## Highpass

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model beta_param lowpass  \
# 70   BCResMax_LA_        0.7   False
# 68   BCResMax_LA_        0.7   False
# 69   BCResMax_LA_        0.7   False
# 100   DDWSseq_LA_        0.7   False
# 96    DDWSseq_LA_        0.7   False
# 95    DDWSseq_LA_        0.7   False
# 41       LCNN_LA_        0.7   False
# 42       LCNN_LA_        0.7   False
# 43       LCNN_LA_        0.7   False
# 14     ResMax_LA_        0.7   False
# 15     ResMax_LA_        0.7   False
# 16     ResMax_LA_        0.7   False
#
#                                            highpass ranfilter2  eer_val  \
# 70   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0048
# 68   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0062
# 69   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0068
# 100  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0048
# 96   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0066
# 95   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0085
# 41   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0036
# 42   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0030
# 43   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0032
# 14   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0054
# 15   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0067
# 16   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0055
#
#      eer_eval
# 70     0.0260
# 68     0.0300
# 69     0.0329
# 100    0.0262
# 96     0.0285
# 95     0.0309
# 41     0.0177
# 42     0.0179
# 43     0.0192
# 14     0.0216
# 15     0.0238
# 16     0.0265

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1681       0.170233      0.001976
# 1   DDWSseq_ADD_        0.1657       0.180367      0.016228
# 2      LCNN_ADD_        0.2017       0.208000      0.006300
# 3    ResMax_ADD_        0.1751       0.182933      0.007751

# %% [markdown]
# ## RP

# %%
df1[df1.highpass == False][df1.lowpass == False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#              model beta_param lowpass highpass               ranfilter2  \
# 77   BCResMax_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 76   BCResMax_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 75   BCResMax_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 103   DDWSseq_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 104   DDWSseq_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 102   DDWSseq_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 50       LCNN_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 48       LCNN_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 49       LCNN_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 21     ResMax_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 23     ResMax_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 22     ResMax_ADD_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
#
#      eer_val  eer_eval
# 77    0.0002    0.1136
# 76    0.0004    0.1356
# 75    0.0010    0.1503
# 103   0.0007    0.1409
# 104   0.0002    0.1440
# 102   1.9221    0.1566
# 50    0.0004    0.1877
# 48    0.0000    0.1884
# 49    0.0002    0.1961
# 21    0.0000    0.1479
# 23    0.0000    0.1664
# 22    0.0000    0.1674

# %%
df1[df1.highpass == False][df1.lowpass == False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1136       0.133167      0.018471
# 1   DDWSseq_ADD_        0.1409       0.147167      0.008315
# 2      LCNN_ADD_        0.1877       0.190733      0.004661
# 3    ResMax_ADD_        0.1479       0.160567      0.010981

# %% [markdown]
# ## LP+ HP

# %%
df1[df1.highpass != False][df1.lowpass != False][df1.ranfilter2 == False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#              model                              lowpass  \
# 86   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 84   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 85   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 112   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 113   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 111   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 57       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 59       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 58       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 31     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 30     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 33     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
#
#                                            highpass ranfilter2  eer_val  \
# 86   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0005
# 84   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0013
# 85   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0010
# 112  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0008
# 113  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0003
# 111  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0021
# 57   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0000
# 59   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0000
# 58   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0000
# 31   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0004
# 30   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0002
# 33   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0003
#
#      eer_eval
# 86     0.1356
# 84     0.1720
# 85     0.1793
# 112    0.1643
# 113    0.1776
# 111    0.1884
# 57     0.1986
# 59     0.2024
# 58     0.2125
# 31     0.1824
# 30     0.1877
# 33     0.2150

# %%
df1[df1.highpass != False][df1.lowpass != False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1356       0.162300      0.023409
# 1   DDWSseq_ADD_        0.1643       0.176767      0.012072
# 2      LCNN_ADD_        0.1986       0.204500      0.007184
# 3    ResMax_ADD_        0.1824       0.195033      0.017494

# %% [markdown]
# ## LP + RP

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#              model                              lowpass highpass  \
# 79   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 78   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 80   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 105   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 106   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 107   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 51       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 52       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 53       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 24     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 26     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 25     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
#
#                   ranfilter2  eer_val  eer_eval
# 79   [2, [8, 9, 10, 11, 12]]   0.0002    0.1143
# 78   [2, [8, 9, 10, 11, 12]]   0.0002    0.1199
# 80   [2, [8, 9, 10, 11, 12]]   0.0008    0.1223
# 105  [2, [8, 9, 10, 11, 12]]   0.0004    0.1283
# 106  [2, [8, 9, 10, 11, 12]]   5.7663    0.1643
# 107  [2, [8, 9, 10, 11, 12]]   5.7663    0.1751
# 51   [2, [8, 9, 10, 11, 12]]   1.9221    0.1674
# 52   [2, [8, 9, 10, 11, 12]]   0.0000    0.1838
# 53   [2, [8, 9, 10, 11, 12]]   0.0000    0.1911
# 24   [2, [8, 9, 10, 11, 12]]   0.0000    0.1496
# 26   [2, [8, 9, 10, 11, 12]]   0.0000    0.1541
# 25   [2, [8, 9, 10, 11, 12]]   0.0000    0.1747

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1143       0.118833      0.004105
# 1   DDWSseq_ADD_        0.1283       0.155900      0.024505
# 2      LCNN_ADD_        0.1674       0.180767      0.012138
# 3    ResMax_ADD_        0.1496       0.159467      0.013383

# %% [markdown]
# ## HP + RP

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#              model lowpass                                        highpass  \
# 83   BCResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 82   BCResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 81   BCResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 110   DDWSseq_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 108   DDWSseq_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 109   DDWSseq_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 54       LCNN_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 56       LCNN_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 55       LCNN_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 29     ResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 27     ResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 28     ResMax_ADD_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
#
#                   ranfilter2  eer_val  eer_eval
# 83   [2, [8, 9, 10, 11, 12]]   0.0010    0.1426
# 82   [2, [8, 9, 10, 11, 12]]   0.0004    0.1464
# 81   [2, [8, 9, 10, 11, 12]]   0.0002    0.1472
# 110  [2, [8, 9, 10, 11, 12]]   0.0008    0.1430
# 108  [2, [8, 9, 10, 11, 12]]   0.0007    0.1496
# 109  [2, [8, 9, 10, 11, 12]]   0.0002    0.1541
# 54   [2, [8, 9, 10, 11, 12]]   0.0003    0.1954
# 56   [2, [8, 9, 10, 11, 12]]   0.0000    0.1954
# 55   [2, [8, 9, 10, 11, 12]]   0.0002    0.2087
# 29   [2, [8, 9, 10, 11, 12]]   0.0003    0.1489
# 27   [2, [8, 9, 10, 11, 12]]   1.9221    0.1674
# 28   [2, [8, 9, 10, 11, 12]]   5.7663    0.1783

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1426       0.145400      0.002458
# 1   DDWSseq_ADD_        0.1430       0.148900      0.005583
# 2      LCNN_ADD_        0.1954       0.199833      0.007679
# 3    ResMax_ADD_        0.1489       0.164867      0.014863

# %% [markdown]
# ## HP + LP + RP

# %%
df1[df1.highpass != False ][df1.highpass !=-999][df1.lowpass != False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#              model                              lowpass  \
# 88   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 87   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 89   BCResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 116   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 115   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 114   DDWSseq_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 60       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 62       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 61       LCNN_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 34     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 32     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 35     ResMax_ADD_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
#
#                                            highpass               ranfilter2  \
# 88   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 87   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 89   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 116  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 115  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 114  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 60   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 62   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 61   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 34   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 32   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 35   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
#
#      eer_val  eer_eval
# 88    0.0004    0.1377
# 87    0.0000    0.1457
# 89    1.9221    0.1464
# 116   0.0004    0.1433
# 115   3.8442    0.1447
# 114   0.0003    0.1541
# 60    0.0000    0.1737
# 62    0.0000    0.1846
# 61    0.0003    0.1916
# 34    5.7663    0.1520
# 32    0.0000    0.1643
# 35    0.0004    0.1846

# %%
df1[df1.highpass != False ][df1.highpass !=-999][df1.lowpass != False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_ADD_        0.1377       0.143267      0.004834
# 1   DDWSseq_ADD_        0.1433       0.147367      0.005873
# 2      LCNN_ADD_        0.1737       0.183300      0.009021
# 3    ResMax_ADD_        0.1520       0.166967      0.016463

# %% [markdown]
# ## 2.2 ASV 2019 Data set
# --------

# %%
import numpy as np

import os
import pandas as pd
import pickle
#from models.BCresnet2 import get_BCResNet, get_inputshape
from sklearn.metrics import roc_curve
from utils.DataLoader import data_loader
from utils.Generator0 import DataGenerator, feature_extract_cqt, evalEER,  evalScore, evalEER_f, evalEER_f2, gen_fname


reslist = ['res_blur_LA/'+fnm for fnm in os.listdir('res_blur_LA/')]

data = []
allkeys = []
for i in range(len(reslist)) :
    with open(reslist[i], 'rb') as f:
        data1 = pickle.load(f)
    data.append(data1)
    allkeys += data1.keys()

allkeys = list(set(allkeys))

newlist = {}
for i in range(len(data)) :
    if i == 0 :
        for k1 in allkeys :
            try :
                newlist[k1] = [ data[i][k1] ]
            except :
                newlist[k1] = [-999]
    else :
        for k1 in allkeys :
            try :
                newlist[k1].append(data[i][k1])
            except :
                newlist[k1].append(-999)

df1 = pd.DataFrame(newlist)
df1.eer_val = pd.to_numeric(df1.eer_val)
df1.eer_eval = pd.to_numeric(df1.eer_eval)

# %%
df1.to_excel(excel_writer="df1_LA_blur.xlsx")

# %%
len(df1)
# Out:
# 116

# %%
len(df1)
# Out:
# 114

# %%
df1[['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']]
# Out:
#           model beta_param                              lowpass  \
# 0    ResMax_LA_      False                                False
# 1    ResMax_LA_      False                                False
# 2    ResMax_LA_      False                                False
# 3    ResMax_LA_      False                                False
# 4    ResMax_LA_      False                                False
# ..          ...        ...                                  ...
# 92  DDWSseq_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 93  DDWSseq_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 94  DDWSseq_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 95  DDWSseq_LA_        0.7                                False
# 96  DDWSseq_LA_        0.7                                False
#
#                                           highpass ranfilter2  eer_val  \
# 0                                            False      False   0.0071
# 1                                            False      False   0.0071
# 2                                            False      False   0.0061
# 3                                            False      False   0.0093
# 4                                            False      False   0.0071
# ..                                             ...        ...      ...
# 92                                           False      False   0.0063
# 93                                           False      False   0.0067
# 94                                           False      False   0.0050
# 95  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0085
# 96  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0066
#
#     eer_eval
# 0     0.0513
# 1     0.0430
# 2     0.0353
# 3     0.0403
# 4     0.0371
# ..       ...
# 92    0.0390
# 93    0.0403
# 94    0.0317
# 95    0.0309
# 96    0.0285
#
# [97 rows x 7 columns]

# %% [markdown]
# ## None

# %%
df1[df1.beta_param== False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model beta_param lowpass highpass ranfilter2  eer_val  eer_eval
# 61  BCResMax_LA_      False   False    False      False   0.0063    0.0338
# 60  BCResMax_LA_      False   False    False      False   0.0054    0.0339
# 59  BCResMax_LA_      False   False    False      False   0.0059    0.0378
# 87   DDWSseq_LA_      False   False    False      False   0.0055    0.0233
# 86   DDWSseq_LA_      False   False    False      False   0.0046    0.0271
# 88   DDWSseq_LA_      False   False    False      False   0.0042    0.0301
# 32      LCNN_LA_      False   False    False      False   0.0036    0.0301
# 34      LCNN_LA_      False   False    False      False   0.0049    0.0338
# 33      LCNN_LA_      False   False    False      False   0.0050    0.0368
# 2     ResMax_LA_      False   False    False      False   0.0061    0.0353
# 4     ResMax_LA_      False   False    False      False   0.0071    0.0371
# 3     ResMax_LA_      False   False    False      False   0.0093    0.0403
# 8     ResMax_LA_      False   False    False      False   0.0086    0.0414
# 9     ResMax_LA_      False   False    False      False   0.0069    0.0414
# 1     ResMax_LA_      False   False    False      False   0.0071    0.0430
# 5     ResMax_LA_      False   False    False      False   0.0073    0.0468
# 10    ResMax_LA_      False   False    False      False   0.0082    0.0481
# 0     ResMax_LA_      False   False    False      False   0.0071    0.0513

# %%
df1[df1.beta_param== False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0338       0.035167      0.002281
# 1   DDWSseq_LA_        0.0233       0.026833      0.003408
# 2      LCNN_LA_        0.0301       0.033567      0.003356
# 3    ResMax_LA_        0.0353       0.042744      0.005187

# %% [markdown]
# ## Mixup

# %%
df1[df1.beta_param!= False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model beta_param lowpass highpass ranfilter2  eer_val  eer_eval
# 63  BCResMax_LA_        0.7   False    False      False   0.0080    0.0319
# 64  BCResMax_LA_        0.7   False    False      False   0.0070    0.0348
# 62  BCResMax_LA_        0.7   False    False      False   0.0076    0.0395
# 89   DDWSseq_LA_        0.7   False    False      False   0.0047    0.0300
# 90   DDWSseq_LA_        0.7   False    False      False   0.0062    0.0330
# 91   DDWSseq_LA_        0.7   False    False      False   0.0044    0.0355
# 37      LCNN_LA_        0.7   False    False      False   0.0042    0.0297
# 36      LCNN_LA_        0.7   False    False      False   0.0037    0.0314
# 35      LCNN_LA_        0.7   False    False      False   0.0047    0.0316
# 99    ResMax_LA_        0.7   False    False      False   0.0075    0.0313
# 97    ResMax_LA_        0.7   False    False      False   0.0062    0.0334
# 98    ResMax_LA_        0.7   False    False      False   0.0072    0.0353

# %%
df1[df1.beta_param!= False][df1.highpass == False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0319       0.035400      0.003835
# 1   DDWSseq_LA_        0.0300       0.032833      0.002754
# 2      LCNN_LA_        0.0297       0.030900      0.001044
# 3    ResMax_LA_        0.0313       0.033333      0.002001

# %% [markdown]
# ### Lowpass

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 == False][['model', 'beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#            model beta_param                              lowpass highpass  \
# 65  BCResMax_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 67  BCResMax_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 66  BCResMax_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 94   DDWSseq_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 92   DDWSseq_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 93   DDWSseq_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 38      LCNN_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 40      LCNN_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 39      LCNN_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 11    ResMax_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 7     ResMax_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 13    ResMax_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 6     ResMax_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 12    ResMax_LA_        0.7  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
#
#    ranfilter2  eer_val  eer_eval
# 65      False   0.0064    0.0324
# 67      False   0.0091    0.0390
# 66      False   0.0081    0.0473
# 94      False   0.0050    0.0317
# 92      False   0.0063    0.0390
# 93      False   0.0067    0.0403
# 38      False   0.0040    0.0277
# 40      False   0.0066    0.0290
# 39      False   0.0036    0.0294
# 11      False   0.0062    0.0337
# 7       False   0.0068    0.0355
# 13      False   0.0056    0.0378
# 6       False   0.0075    0.0380
# 12      False   0.0069    0.0383

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0324       0.039567      0.007466
# 1   DDWSseq_LA_        0.0317       0.037000      0.004636
# 2      LCNN_LA_        0.0277       0.028700      0.000889
# 3    ResMax_LA_        0.0337       0.036660      0.001993

# %% [markdown]
# ## Highpass

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 == False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model lowpass                                        highpass  \
# 70   BCResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 68   BCResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 69   BCResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 100   DDWSseq_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 96    DDWSseq_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 95    DDWSseq_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 41       LCNN_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 42       LCNN_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 43       LCNN_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 14     ResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 15     ResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 16     ResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
#
#     ranfilter2  eer_val  eer_eval
# 70       False   0.0048    0.0260
# 68       False   0.0062    0.0300
# 69       False   0.0068    0.0329
# 100      False   0.0048    0.0262
# 96       False   0.0066    0.0285
# 95       False   0.0085    0.0309
# 41       False   0.0036    0.0177
# 42       False   0.0030    0.0179
# 43       False   0.0032    0.0192
# 14       False   0.0054    0.0216
# 15       False   0.0067    0.0238
# 16       False   0.0055    0.0265

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0260       0.029633      0.003465
# 1   DDWSseq_LA_        0.0262       0.028533      0.002350
# 2      LCNN_LA_        0.0177       0.018267      0.000814
# 3    ResMax_LA_        0.0216       0.023967      0.002454

# %% [markdown]
# ## RP

# %%
df1[df1.highpass == False][df1.lowpass == False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values( ['model','eer_eval'] )
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model beta_param lowpass highpass               ranfilter2  \
# 71   BCResMax_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 72   BCResMax_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 73   BCResMax_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 103   DDWSseq_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 102   DDWSseq_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 101   DDWSseq_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 44       LCNN_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 45       LCNN_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 46       LCNN_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 17     ResMax_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 18     ResMax_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
# 19     ResMax_LA_        0.7   False    False  [2, [8, 9, 10, 11, 12]]
#
#      eer_val  eer_eval
# 71    0.0085    0.0454
# 72    0.0075    0.0517
# 73    0.0070    0.0536
# 103   0.0060    0.0346
# 102   0.0058    0.0417
# 101   0.0078    0.0429
# 44    0.0026    0.0334
# 45    0.0042    0.0386
# 46    0.0037    0.0417
# 17    0.0055    0.0350
# 18    0.0077    0.0431
# 19    0.0070    0.0447

# %%
df1[df1.highpass == False][df1.lowpass == False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0454       0.050233      0.004292
# 1   DDWSseq_LA_        0.0346       0.039733      0.004486
# 2      LCNN_LA_        0.0334       0.037900      0.004194
# 3    ResMax_LA_        0.0350       0.040933      0.005200

# %% [markdown]
# ## LP+ HP

# %%
df1[df1.highpass != False][df1.lowpass != False][df1.ranfilter2 == False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model                              lowpass  \
# 81   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 82   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 80   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 112   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 111   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 110   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 54       LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 55       LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 53       LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 27     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 26     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 28     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
#
#                                            highpass ranfilter2  eer_val  \
# 81   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0069
# 82   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0067
# 80   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0081
# 112  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0070
# 111  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0059
# 110  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0051
# 54   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0042
# 55   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0037
# 53   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0046
# 27   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0050
# 26   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0055
# 28   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]      False   0.0054
#
#      eer_eval
# 81     0.0276
# 82     0.0278
# 80     0.0320
# 112    0.0244
# 111    0.0262
# 110    0.0314
# 54     0.0172
# 55     0.0193
# 53     0.0198
# 27     0.0207
# 26     0.0233
# 28     0.0252

# %%
df1[df1.highpass != False][df1.lowpass != False][df1.ranfilter2 == False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0276       0.029133      0.002485
# 1   DDWSseq_LA_        0.0244       0.027333      0.003635
# 2      LCNN_LA_        0.0172       0.018767      0.001380
# 3    ResMax_LA_        0.0207       0.023067      0.002259

# %% [markdown]
# ## LP + RP

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model                              lowpass highpass  \
# 75   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 76   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 74   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 106   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 104   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 105   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 49       LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 47       LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 48       LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 22     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 21     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
# 20     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]    False
#
#                   ranfilter2  eer_val  eer_eval
# 75   [2, [8, 9, 10, 11, 12]]   0.0075    0.0563
# 76   [2, [8, 9, 10, 11, 12]]   0.0070    0.0566
# 74   [2, [8, 9, 10, 11, 12]]   0.0083    0.0599
# 106  [2, [8, 9, 10, 11, 12]]   0.0089    0.0400
# 104  [2, [8, 9, 10, 11, 12]]   0.0069    0.0542
# 105  [2, [8, 9, 10, 11, 12]]   0.0054    0.0676
# 49   [2, [8, 9, 10, 11, 12]]   0.0039    0.0340
# 47   [2, [8, 9, 10, 11, 12]]   0.0039    0.0353
# 48   [2, [8, 9, 10, 11, 12]]   0.0059    0.0422
# 22   [2, [8, 9, 10, 11, 12]]   0.0068    0.0430
# 21   [2, [8, 9, 10, 11, 12]]   0.0090    0.0491
# 20   [2, [8, 9, 10, 11, 12]]   0.0082    0.0500

# %%
df1[df1.highpass == False][df1.lowpass != False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0563       0.057600      0.001997
# 1   DDWSseq_LA_        0.0400       0.053933      0.013802
# 2      LCNN_LA_        0.0340       0.037167      0.004407
# 3    ResMax_LA_        0.0430       0.047367      0.003808

# %% [markdown]
# ## HP + RP

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model lowpass                                        highpass  \
# 79   BCResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 77   BCResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 78   BCResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 107   DDWSseq_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 108   DDWSseq_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 109   DDWSseq_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 52       LCNN_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 51       LCNN_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 50       LCNN_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 24     ResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 23     ResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
# 25     ResMax_LA_   False  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]
#
#                   ranfilter2  eer_val  eer_eval
# 79   [2, [8, 9, 10, 11, 12]]   0.0078    0.0376
# 77   [2, [8, 9, 10, 11, 12]]   0.0059    0.0381
# 78   [2, [8, 9, 10, 11, 12]]   0.0084    0.0463
# 107  [2, [8, 9, 10, 11, 12]]   0.0069    0.0356
# 108  [2, [8, 9, 10, 11, 12]]   0.0063    0.0408
# 109  [2, [8, 9, 10, 11, 12]]   0.0071    0.0459
# 52   [2, [8, 9, 10, 11, 12]]   0.0031    0.0258
# 51   [2, [8, 9, 10, 11, 12]]   0.0042    0.0278
# 50   [2, [8, 9, 10, 11, 12]]   0.0049    0.0290
# 24   [2, [8, 9, 10, 11, 12]]   0.0052    0.0288
# 23   [2, [8, 9, 10, 11, 12]]   0.0052    0.0313
# 25   [2, [8, 9, 10, 11, 12]]   0.0059    0.0372

# %%
df1[df1.highpass != False][df1.lowpass == False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0376       0.040667      0.004885
# 1   DDWSseq_LA_        0.0356       0.040767      0.005150
# 2      LCNN_LA_        0.0258       0.027533      0.001617
# 3    ResMax_LA_        0.0288       0.032433      0.004313

# %% [markdown]
# ## HP + LP + RP

# %%
df1[df1.highpass != False ][df1.highpass !=-999][df1.lowpass != False][df1.ranfilter2 != False][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values(['model','eer_eval'])
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model                              lowpass  \
# 83   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 85   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 84   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 115   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 113   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 114   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 57       LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 56       LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 58       LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 29     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 30     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 31     ResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
#
#                                            highpass               ranfilter2  \
# 83   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 85   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 84   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 115  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 113  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 114  [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 57   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 56   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 58   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 29   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 30   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
# 31   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]  [2, [8, 9, 10, 11, 12]]
#
#      eer_val  eer_eval
# 83    0.0063    0.0338
# 85    0.0072    0.0385
# 84    0.0076    0.0395
# 115   0.0070    0.0335
# 113   0.0082    0.0349
# 114   0.0078    0.0530
# 57    0.0040    0.0221
# 56    0.0039    0.0225
# 58    0.0043    0.0243
# 29    0.0046    0.0320
# 30    0.0062    0.0340
# 31    0.0077    0.0357

# %%
df1[df1.highpass != False ][df1.highpass !=-999][df1.lowpass != False][df1.ranfilter2 != False][['model','beta_param','lowpass','highpass','ranfilter2','eer_val','eer_eval']].groupby('model')['eer_eval'].agg(**{
    'min_eer_eval':'min',
    'mean_eer_eval':'mean',
    'std_eer_eval' :'std'
}).reset_index()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           model  min_eer_eval  mean_eer_eval  std_eer_eval
# 0  BCResMax_LA_        0.0338       0.037267      0.003044
# 1   DDWSseq_LA_        0.0335       0.040467      0.010877
# 2      LCNN_LA_        0.0221       0.022967      0.001172
# 3    ResMax_LA_        0.0320       0.033900      0.001852

# %% [markdown]
# ## 가장 성능이 좋은 모델 확인

# %%
df1[df1.model!="ResMax_LA_"][df1.eer_eval <= 0.15][['model','lowpass','highpass','ranfilter2','eer_val','eer_eval']].sort_values('eer_eval')
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2.4_p37/lib/python3.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#             model                              lowpass  \
# 54       LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 41       LCNN_LA_                                False
# 42       LCNN_LA_                                False
# 43       LCNN_LA_                                False
# 55       LCNN_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# ..            ...                                  ...
# 104   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 75   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 76   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 74   BCResMax_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
# 105   DDWSseq_LA_  [[0.5, 0.5], [7, 8, 9, 10, 11, 12]]
#
#                                            highpass               ranfilter2  \
# 54   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]                    False
# 41   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]                    False
# 42   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]                    False
# 43   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]                    False
# 55   [[0.5, 0.5], [80, 81, 82, 83, 84, 85, 86, 87]]                    False
# ..                                              ...                      ...
# 104                                           False  [2, [8, 9, 10, 11, 12]]
# 75                                            False  [2, [8, 9, 10, 11, 12]]
# 76                                            False  [2, [8, 9, 10, 11, 12]]
# 74                                            False  [2, [8, 9, 10, 11, 12]]
# 105                                           False  [2, [8, 9, 10, 11, 12]]
#
#      eer_val  eer_eval
# 54    0.0042    0.0172
# 41    0.0036    0.0177
# 42    0.0030    0.0179
# 43    0.0032    0.0192
# 55    0.0037    0.0193
# ..       ...       ...
# 104   0.0069    0.0542
# 75    0.0075    0.0563
# 76    0.0070    0.0566
# 74    0.0083    0.0599
# 105   0.0054    0.0676
#
# [81 rows x 6 columns]
